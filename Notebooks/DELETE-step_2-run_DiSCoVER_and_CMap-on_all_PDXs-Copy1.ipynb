# %% [markdown]
# ## RNASeq workflow for PDX-HTS paper

# %% [markdown]
# This notebook contains all the analyses...

# %%
# Performing common imports ... a few other imports are made automatically by UIBuilder cells bellow. Don't delete them!
from common_imports import *

# %%
#Setting the random number generator seed. This is used by Sklearn's Random Forrest Classifier. Not a crucial part of the pipeline, more like an optional display -- but reproducibility is imperative
np.random.seed(0)

# %%
CLASSIFY = False
RUN_DISCOVER = True

# %%
def run_pipeline(case_id):
    print('======================================')
    print("Step 1: read_user_input")
    print('======================================')
    setup = read_user_input(case_id, patient_dir=case_id, dna_nexus_bool=False, is_medullo=True, control='original',custom_control_expression='N/A')
    print('======================================')
    print("Step 2: download_and_preprocess_rnaseq")
    print('======================================')
    setup = download_and_preprocess_rnaseq(setup)
    print('======================================')
    print("Step 3: classify_sample")
    print('======================================')
    if CLASSIFY:
        setup = classify_sample(setup)
    else:
         print("These are not the analyses you are looking for. Move along!")   
    print('======================================')
    print("Step 4: run_discover")
    print('======================================')
    if RUN_DISCOVER:
        setup = run_discover(setup)
    else:
        print("These are not the analyses you are looking for. Move along!") 
        setup = pickle.load(file=open(os.path.join(setup.out_dir, setup.case_id+'_backup4_DISCoVER.p'),'rb'))
    print('======================================')
#     print("Step 5: run_cmap")
#     print('======================================')
#     setup = make_cmap_slide(setup)
#     setup = merge_discover_and_cmap(setup)
    print(f'All analyses completed suscessfully with "patient" {case_id}')
    return

# %%
# "BT084"
run_pipeline('BT084')
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/BT084.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, BT084 to BT084
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/BT084/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# ==> About to perform DiSCoVER.
# Modifying it on 2018-11-26
# Loading CTRP
# Projecting disease gene sets
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# ssGSEA results for ctrp
#                     BT084
# NCIH524          0.411373
# DMS273           0.379387
# NCIH1184         0.363872
# HCC33            0.318098
# NCIH446          0.316984
# NCIH1155         0.311920
# NCIH810          0.287450
# IMR32            0.281851
# NCIH1341         0.273424
# D283MED          0.271184
# KMS11            0.270547
# COLO668          0.264934
# DMS53            0.263698
# DAOY             0.258990
# DMS454           0.255795
# DMS114           0.254353
# G292CLONEA141B1  0.252999
# 5637             0.251977
# DU145            0.251220
# SNU503           0.239764
# Matching to drug response profiles
# Loading GDSC
# Projecting disease gene sets
# ssGSEA results for gdsc
#                    BT084 COSMIC ID
# cosmic_907170   0.013518    907170
# cosmic_753589   0.008829    753589
# cosmic_688022  -0.001260    688022
# cosmic_753582  -0.011486    753582
# cosmic_753594  -0.014332    753594
# cosmic_688006  -0.015540    688006
# cosmic_687804  -0.015733    687804
# cosmic_908483  -0.023991    908483
# cosmic_713899  -0.027119    713899
# cosmic_908135  -0.035457    908135
# cosmic_688031  -0.037490    688031
# cosmic_910941  -0.047185    910941
# cosmic_688027  -0.050127    688027
# cosmic_949173  -0.050185    949173
# cosmic_713878  -0.053642    713878
# cosmic_687997  -0.058183    687997
# cosmic_753547  -0.059176    753547
# cosmic_1322213 -0.059496   1322213
# cosmic_688023  -0.063410    688023
# cosmic_910937  -0.064294    910937
# Matching to drug response profiles
# Loading CCLE
# Projecting disease gene sets
# ssGSEA results for ccle
#              BT084
# NCIH1184  0.363872
# NCIH1694  0.363692
# NCIH1155  0.311920
# NCIH1092  0.306637
# NCIH810   0.287450
# IMR32     0.281851
# NCIH1341  0.273424
# KMS11     0.270547
# DAOY      0.258990
# DMS114    0.254353
# TC71      0.253493
# 5637      0.251977
# DU145     0.251220
# NCIH1048  0.248959
# NCIH211   0.238934
# KYSE450   0.236202
# HARA      0.230910
# MFE280    0.230709
# SKNDZ     0.229627
# RD        0.229290
# Matching to drug response profiles
# ==> DiSCoVER done!
# ==> Saving results to file.
# ==> Saving done!
# ==> NOT Restricting to clinically relevant drugs.
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> Done restricting to clinically relevant drugs!
# ==> Making the DiSCoVER powerpoint.
# ==> Using all of the drugs
# ==> Done making the DiSCoVER powerpoint slide!
# ==> Savig the variables to a file.
# ==> Saving the formatted results of DiSCoVER to a csv
# ==> Done savig the variables to a file!
# ==> Done with all the taks in this cell. Move along.
# ======================================
# All analyses completed suscessfully with "patient" BT084

# %% [markdown]
# ### Parsing the COSMIC cell lines (produced by GDSC)

# %%
from xml.etree import ElementTree

# %%
e = ElementTree.parse('data/raw/cellosaurus/cellosaurus.xml').getroot()
clist = e.findall('cell-line-list')[0]

# %%
temp = lambda: None
temp.what = 'temp'
temp.what
# create a cell line object, add to a running dictionary? pandas dataframe?
# Out:
# 'temp'

# %%
print(f'There are {len(clist)} cell lines!')
cosmic_lines = pd.DataFrame()
row = pd.Series(index=['CellosaurusID','Names','Databases','CosmicIDs','Disease'])

for cline in clist:
    if (cline.findall('xref-list') is not None) and (len(cline.findall('xref-list')) is not 0) and ('Cosmic' in [xref.attrib['database'] for xref in cline.find('xref-list').findall('xref')]):
    
        print('CellosaurusID:')
        # accession-list appears exactly once:
        #<xs:element ref="accession-list" minOccurs="1" maxOccurs="1"/>
        print([x.text for x in cline.find('accession-list').findall('accession')])
        row['CellosaurusID'] = [x.text for x in cline.find('accession-list').findall('accession')]
        row.name = row['CellosaurusID'][0]

        print('Names:')
        # name-list appears exactly once:
        #<xs:element ref="name-list" minOccurs="1" maxOccurs="1"/>
        print([x.text for x in cline.find('name-list').findall('name')])
        row['Names'] = [x.text for x in cline.find('name-list').findall('name')]

        print('Databases:')
        if (cline.findall('xref-list') is not None) and (len(cline.findall('xref-list')) is not 0):
            # xref-list may not appear, but appears at most once
            #<xs:element ref="xref-list" minOccurs="0" maxOccurs="1"/>
            xrefs = [xref for xref in cline.find('xref-list').findall('xref')]
            databases = [xref.attrib['database'] for xref in cline.find('xref-list').findall('xref')]
            print(databases)
        else:
            databases = None
            print(databases)
        row['Databases'] = databases
        
        print('CosmicIDs:')
        if databases is not None:
            # xref-list may not appear, but appears at most once
            #<xs:element ref="xref-list" minOccurs="0" maxOccurs="1"/>
            cids = [xref.attrib['accession'] for xref in xrefs if xref.attrib['database']=='Cosmic']
            print(cids)
        else:
            cids = None
            print(cids)
        row['CosmicIDs'] = cids

        print('Disease:')
        if cline.find('disease-list') is not None: 
            # disease-list may not appear, but appears at most once
            # <xs:element ref="disease-list" minOccurs="0" maxOccurs="1"/>
            d_list = [x.text for x in cline.find('disease-list').findall('cv-term')]
            print(d_list)
        else:
            d_list = None
            print(d_list)
        
        if d_list is not None:
            if len(d_list)==1:
                d_list = d_list[0]
            else:
                print("There are multiple diceases, this is unexpected")
                d_list = d_list
        else:
            print("Wow, no disease associated.")
            d_list = ''
        
        row['Disease'] = d_list
        cosmic_lines = cosmic_lines.append(row,verify_integrity=True)


        print('---')
# Out:
# There are 109135 cell lines!
# CellosaurusID:
# ['CVCL_D231']
# Names:
# ['1-87']
# Databases:
# ['ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['889083', '946049', '1066155']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_7942']
# Names:
# ['1011-mel', '1011-MEL', '1011 mel', '1011mel', '1011', 'Mel 1011']
# Databases:
# ['CGH-DB', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['876687', '905206']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_4806']
# Names:
# ['1013L', '1013-L']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['721372']
# Disease:
# ['Prostate carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8029']
# Names:
# ['1088-mel', '1088-MEL', '1088 Mel', '1088 mel', '1088']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876702']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_VJ83']
# Names:
# ['10CM', '10 CM']
# Databases:
# ['Cosmic']
# CosmicIDs:
# ['2543722']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_D856']
# Names:
# ['11-18-ER1-7', '11-18/ER1-7']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1731373']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_D857']
# Names:
# ['11-18-ER2-1', '11-18/ER2-1']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1731374']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_D776']
# Names:
# ['11-18-GEF10-1', '11-18/GEF10-1']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1731375']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_D777']
# Names:
# ['11-18-GEF20-1', '11-18/GEF20-1']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1731376']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_S745']
# Names:
# ['11-18/R', '11-18R', '11-18/ER']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1890459']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_8030']
# Names:
# ['1102-mel', '1102-MEL', '1102 mel', '1102mel', '1102', 'MEL1102']
# Databases:
# ['BTO', 'CGH-DB', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['905207', '972280']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8031']
# Names:
# ['1143-mel', '1143-MEL', '1143 mel', '1143']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876688']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8033']
# Names:
# ['1195-mel', '1195-MEL', '1195 mel', '1195']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876689']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8034']
# Names:
# ['1199-mel', '1199-MEL', '1199 mel', '1199']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876690']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_VJ84']
# Names:
# ['11CM', '11 CM']
# Databases:
# ['Cosmic']
# CosmicIDs:
# ['2543723']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_5239']
# Names:
# ['1205Lu', '1205-Lu', '1205 Lu', 'WM 1205LU', 'WM-1205LU', 'WM1205Lu', 'WM1205', 'LU1205', 'Lu1205', 'WC00058']
# Databases:
# ['BTO', 'CLO', 'EFO', 'ATCC', 'BioSample', 'Coriell', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'ESTDAB', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Lonza', 'PRIDE', 'SKY/M-FISH/CGH', 'Wikidata']
# CosmicIDs:
# ['686410', '905861', '972275', '1155274', '1155554', '1187583', '1303026', '1507616']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_N588']
# Names:
# ['1273/99', '1273']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2307723']
# Disease:
# ['Synovial sarcoma']
# ---
# CellosaurusID:
# ['CVCL_8036']
# Names:
# ['1280-mel', '1280-MEL', '1280 mel', '1280']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876691']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_7943']
# Names:
# ['1290-mel', '1290-MEL', '1290 mel', '1290', 'MG-1290', '1290-MEL p14', '1290p14']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876682', '877280', '1042622']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_0Q73']
# Names:
# ['12Z', '12z', '12-Z', 'Z12', 'Z-12']
# Databases:
# ['BTO', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1432838']
# Disease:
# ['Endometriosis']
# ---
# CellosaurusID:
# ['CVCL_8039']
# Names:
# ['1300-mel', '1300-MEL', '1300 mel', '1300']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876703']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_2265']
# Names:
# ['1301']
# Databases:
# ['CLO', 'CLDB', 'CCRID', 'Cosmic', 'ECACC', 'ICLC', 'NCBI_Iran', 'Wikidata']
# CosmicIDs:
# ['2402466']
# Disease:
# ['Childhood T acute lymphoblastic leukemia']
# ---
# CellosaurusID:
# ['CVCL_8040']
# Names:
# ['1317-mel', '1317-MEL', '1317 mel', '1317']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876692']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_Z019']
# Names:
# ['1335-mel', '1335-MEL']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876693']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_Z020']
# Names:
# ['1352-mel', '1352-MEL']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876694']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8041']
# Names:
# ['1359-mel', '1359-MEL', '1359 mel', '1359', 'Mel-1359']
# Databases:
# ['Cosmic', 'ESTDAB', 'Wikidata']
# CosmicIDs:
# ['2163791']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W281']
# Names:
# ['136-2']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1418452']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S560']
# Names:
# ['1362-mel', '1362-MEL', '1362 mel', '1362mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905208']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8042']
# Names:
# ['1363-mel', '1363-MEL', '1363 mel', '1363']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876704']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8043']
# Names:
# ['1376-mel', '1376-MEL', '1376 mel', '1376']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876695']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8044']
# Names:
# ['1383-mel', '1383-MEL', '1383 mel', '1383']
# Databases:
# ['BTO', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['876696']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8046']
# Names:
# ['1390-mel', '1390-MEL', '1390 mel', '1390']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876697']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_2268']
# Names:
# ['1411H', '1411HP']
# Databases:
# ['Cosmic', 'Cosmic', 'ECACC', 'Wikidata']
# CosmicIDs:
# ['2077184', '2439937']
# Disease:
# ['Testicular embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_2270']
# Names:
# ['143B', '143b', '143 B', '143B TK-', '143BTK-', '143TK-', 'HOS-143B', 'HOS-143b', 'GM05887']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Coriell', 'Cosmic', 'Cosmic', 'Cosmic', 'ECACC', 'GEO', 'GEO', 'GEO', 'GEO', 'IZSLER', 'LINCS_LDP', 'Lonza', 'TOKU-E', 'Wikidata']
# CosmicIDs:
# ['1074398', '1529910', '2009541']
# Disease:
# ['Osteosarcoma']
# ---
# CellosaurusID:
# ['CVCL_8047']
# Names:
# ['1479-mel', '1479-MEL', '1479 mel', '1479', 'Mel-1479']
# Databases:
# ['Cosmic', 'ESTDAB', 'Wikidata']
# CosmicIDs:
# ['2163792']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_M136']
# Names:
# ['1580WU', 'Wu-1580']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2362659']
# Disease:
# ['Medulloblastoma']
# ---
# CellosaurusID:
# ['CVCL_0B41']
# Names:
# ['169A']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2163759']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_D704']
# Names:
# ['17-94', '17.94', '17,94']
# Databases:
# ['Cosmic', 'DSMZ', 'Wikidata', 'Ximbio']
# CosmicIDs:
# ['1716565']
# Disease:
# ['Renal Wilms tumor']
# ---
# CellosaurusID:
# ['CVCL_S817']
# Names:
# ['1765-92', 'MLS 1765-92', 'MLS-1765', 'MLS1765']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1672268', '2307720']
# Disease:
# ['Myxoid liposarcoma']
# ---
# CellosaurusID:
# ['CVCL_2277']
# Names:
# ['1777N Rpmet', '1777N RpMet', '1777N RPMET', '1777N']
# Databases:
# ['Cosmic', 'Cosmic', 'ECACC', 'Wikidata']
# CosmicIDs:
# ['2077189', '2439938']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_U758']
# Names:
# ['1783']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['802250']
# Disease:
# ['Rhabdoid tumor of the kidney']
# ---
# CellosaurusID:
# ['CVCL_AX27']
# Names:
# ['1795/4A', '1795-4A']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2361370']
# Disease:
# ['Lymphoid leukemia']
# ---
# CellosaurusID:
# ['CVCL_DI11']
# Names:
# ['1858-mel a', '1858-MEL a', '1858-MEL a (Fragment)']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1042624']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_DI14']
# Names:
# ['1936-mel', '1936-MEL', '1936-MEL (Medimachine)', 'MG-1936']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1042625']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S815']
# Names:
# ['1955-91', '1955/91', 'MLS 1955-91']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1105000', '1105010']
# Disease:
# ['Myxoid liposarcoma']
# ---
# CellosaurusID:
# ['CVCL_DI15']
# Names:
# ['1962-mel', '1962-MEL', 'MG-1962']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1042626']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_6344']
# Names:
# ['1A6', '5637 subclone 1A6']
# Databases:
# ['CLO', 'ATCC', 'ATCC', 'Cosmic', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['2037945']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_U759']
# Names:
# ['2004']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['802248']
# Disease:
# ['Rhabdoid tumor of the kidney']
# ---
# CellosaurusID:
# ['CVCL_0114']
# Names:
# ['2008/C13*5.25', '2008/C13_5_25', '2008/c13*5.25', 'OV 2008/C13*5.25', 'OV2008/C13', '2008C13', '2008 C-13', 'C13', '2008/C13.R', 'ME180C13']
# Databases:
# ['BTO', 'MCCL', 'BioSample', 'BioSample', 'Cosmic', 'Cosmic', 'GEO', 'NCBI_Iran', 'Wikidata']
# CosmicIDs:
# ['948294', '1479983']
# Disease:
# ['Human papillomavirus-related cervical squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_X481']
# Names:
# ['201T']
# Databases:
# ['ArrayExpress', 'CCLE', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['910550']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_C522']
# Names:
# ['2102EP', '2102Ep']
# Databases:
# ['BTO', 'EFO', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['2077185', '2163762']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_0B42']
# Names:
# ['218A']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2163760']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_0B43']
# Names:
# ['228A']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2163761']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1045']
# Names:
# ['22Rv1', '22RV1', '22Rv-1', '22rV1', 'CWR22-Rv1', 'CWR22R-V1', 'CWR22-R1', 'CWR22Rv1', 'CWR22R']
# Databases:
# ['BTO', 'CLO', 'CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'KCB', 'LINCS_LDP', 'Lonza', 'Wikidata']
# CosmicIDs:
# ['924100', '1075276', '1028699', '1071480', '1172629', '1330911', '1689707', '1995323', '2537791', '2580126', '2651766', '2669170']
# Disease:
# ['Prostate carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1046']
# Names:
# ['23132/87', '23132-87', '2313287', 'St 23132', 'St23132']
# Databases:
# ['CLO', 'EFO', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['910924', '1995324', '2484956']
# Disease:
# ['Gastric adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_7935', 'CVCL_7938']
# Names:
# ['253J', '253j', '253-J', '253 J', '253J-P', '253J-Parental', '253J P', '253JP']
# Databases:
# ['BTO', 'ArrayExpress', 'ATCC', 'CCLE', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'KCLB', 'Wikidata']
# CosmicIDs:
# ['715794', '760476', '845564', '925827', '928820', '1016884', '1046680', '1082644', '1938694', '1285102', '1285997', '1927305', '2050426', '2057433', '2444255', '2685929', '2700994']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_7937']
# Names:
# ['253J-BV', '253JB-V', '253J B-V', '253JBV', '253J-Bladder-V']
# Databases:
# ['BTO', 'ArrayExpress', 'CCLE', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'KCLB', 'Wikidata']
# CosmicIDs:
# ['846282', '1082645', '1938695']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_X482']
# Names:
# ['273T']
# Databases:
# ['Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['910551']
# Disease:
# ['Squamous cell lung carcinoma']
# ---
# CellosaurusID:
# ['CVCL_0B44']
# Names:
# ['27X1']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2163757']
# Disease:
# ['Embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_9557']
# Names:
# ['2957/90', 'St 2957', 'St2957', 'ST2957']
# Databases:
# ['BioSample', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['887218']
# Disease:
# ['Rectosigmoid adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_1047']
# Names:
# ['380']
# Databases:
# ['CLO', 'CLDB', 'CLDB', 'BioSample', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'DSMZ', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'Wikidata']
# CosmicIDs:
# ['924101', '1012056', '1130253', '1524787']
# Disease:
# ['Childhood B acute lymphoblastic leukemia']
# ---
# CellosaurusID:
# ['CVCL_8050']
# Names:
# ['397-mel', '397-MEL', '397-Mel', '397 mel', '397mel', '397']
# Databases:
# ['CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['876699', '905209', '897736', '1295344']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_Y457']
# Names:
# ['3D5 [Human melanoma]']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1058336']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S813']
# Names:
# ['402-91', '402/91', 'MLS 402-91', 'MLS402']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1105011', '1672267', '2307719']
# Disease:
# ['Myxoid liposarcoma']
# ---
# CellosaurusID:
# ['CVCL_N788']
# Names:
# ['41M-cisR', '41M/cisR', '41McisR']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1609533']
# Disease:
# ['High grade ovarian serous adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_Y037']
# Names:
# ['41M47', '41m/47']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['688088', '1609530']
# Disease:
# ['High grade ovarian serous adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_1798']
# Names:
# ['42-MG-BA', '42MGBA']
# Databases:
# ['CLO', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'CCLE', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687561', '1746946', '1995325', '2060804', '2302328']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_6357']
# Names:
# ['451Lu', '451LU', '451-LU', 'WM 451-Lu', 'WM-451Lu', 'WM-451LU', 'WM451Lu', 'WM451', 'WC00059', 'LU451', 'EST81']
# Databases:
# ['BTO', 'CLO', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'Coriell', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ESTDAB', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['686411', '1047656', '1155281', '1155568', '1187587', '1303027', '2163808', '2230114']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_C528']
# Names:
# ['5-8F', '58F']
# Databases:
# ['BTO', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1322951', '1459415']
# Disease:
# ['Nasopharyngeal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_S665']
# Names:
# ['5-8F/Erbitux', '5-8F-Erbitux']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1459416']
# Disease:
# ['Nasopharyngeal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_4633', 'CVCL_C608']
# Names:
# ['501-mel', '501-MEL', '501 mel', '501 Mel', '501Mel', '501mel', '501', 'Mel 501', 'Mel501', 'MEL501', 'Me 501', 'Me-501', 'Me501']
# Databases:
# ['BTO', 'CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'ESTDAB', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'Wikidata']
# CosmicIDs:
# ['686481', '876680', '905210', '1197392', '1238106', '1458962', '1559440', '2159451', '2163827', '2440478']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8051']
# Names:
# ['526-mel', '526-MEL', '526 mel', '526mel', '526MEL', '526', 'MEL-526', 'Mel526', 'MEL526']
# Databases:
# ['CGH-DB', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['905211', '1303043']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8052']
# Names:
# ['537-mel', '537-MEL', '537 mel', '537 MEL', '537mel', '537MEL', '537', 'Mel537']
# Databases:
# ['EFO', 'ArrayExpress', 'BioSample', 'CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876685', '905212', '1507618', '2233664']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W285']
# Names:
# ['553B-mel', '553B mel', '553Bmel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905213']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_0126']
# Names:
# ['5637']
# Databases:
# ['BTO', 'CLO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BCRJ', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IGRhCellID', 'KCLB', 'LINCS_HMS', 'LINCS_LDP', 'NCBI_Iran', 'PRIDE', 'RCB', 'RCB', 'SKY/M-FISH/CGH', 'TKG', 'Wikidata']
# CosmicIDs:
# ['687452', '715695', '760484', '845565', '846281', '928819', '943732', '1016892', '1046675', '1093983', '1285103', '1285998', '1927307', '2050427', '2057434', '2301520', '2444227', '2685930', '2700995']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_7941']
# Names:
# ['575A']
# Databases:
# ['ATCC', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1016885']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_Z021']
# Names:
# ['586-mel', '586-MEL', '586 MEL', '586 Mel', '586 mel']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['876700']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_VK11']
# Names:
# ['587X']
# Databases:
# ['Cosmic']
# CosmicIDs:
# ['2727474']
# Disease:
# ['Colon carcinoma']
# ---
# CellosaurusID:
# ['CVCL_6E55']
# Names:
# ['59M13', '59m/13']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1609532']
# Disease:
# ['High grade ovarian serous adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_C529']
# Names:
# ['6-10B']
# Databases:
# ['BTO', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['2366878']
# Disease:
# ['Nasopharyngeal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_9875', 'CVCL_8287']
# Names:
# ['600MPE', '600 MPE', '600-MPE', 'MPE-600', 'MPE 600', 'MPE600', '600PE', '600-PEI']
# Databases:
# ['CLO', 'EFO', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_HMS', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['997932', '1000128', '1046948', '1091346', '1136351', '1176628', '1287907', '1289403', '2301521']
# Disease:
# ['Invasive ductal carcinoma, not otherwise specified']
# ---
# CellosaurusID:
# ['CVCL_8054']
# Names:
# ['624-mel', '624-MEL', '624 MEL', '624 Mel', '624 mel', '624mel', '624MEL', '624', 'Mel-624', 'Mel624', 'MEL624']
# Databases:
# ['BTO', 'EFO', 'ArrayExpress', 'BioSample', 'CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'ESTDAB', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876683', '905214', '1303044', '1559441', '2163793']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_1048']
# Names:
# ['639V', '639v', '639-V', '639 V']
# Databases:
# ['CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['906798', '923375', '928821', '1285104', '1927315', '2050428', '2685931']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1049']
# Names:
# ['647V', '647-V', '647 V']
# Databases:
# ['CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'LINCS_HMS', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['906797', '928822', '1046676', '1285105', '1286005', '1927309', '2050429', '2057435', '2444239', '2685932']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_H722']
# Names:
# ['6647', '#6647']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1078384', '1082508', '1718435', '2228212']
# Disease:
# ['Ewing sarcoma']
# ---
# CellosaurusID:
# ['CVCL_0079', 'CVCL_8861']
# Names:
# ['697', 'Line 697', 'EU-3', 'Emory University-3']
# Databases:
# ['BTO', 'CLO', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IZSLER', 'LINCS_LDP', 'Lonza', 'Wikidata']
# CosmicIDs:
# ['906800', '1037742', '1130252', '1191693', '1524788', '2396142', '2427693', '2649230']
# Disease:
# ['B acute lymphoblastic leukemia with t(1;19)(q23;p13.3) E2A-PBX1 (TCF3-PBX1)']
# ---
# CellosaurusID:
# ['CVCL_8056']
# Names:
# ['697-mel', '697-MEL', '697 Mel', '697 mel', '697mel', '697']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905215']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S561']
# Names:
# ['729-mel', '729mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905216']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S562']
# Names:
# ['731-mel', '731mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905217']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_1050']
# Names:
# ['769-P', '769P', '769-p']
# Databases:
# ['CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'IZSLER', 'KCB', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687935', '801355', '910922', '982280', '1779197', '2520640']
# Disease:
# ['Renal cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1051']
# Names:
# ['786-O', '786-o', '786O', '786-0', '786.O', '786-O RCC', 'RCC 786-O', 'RCC_7860', 'RCC 7860', '7860', '786-0WT']
# Databases:
# ['BTO', 'CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ENCODE', 'ENCODE', 'ENCODE', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IZSLER', 'KCB', 'LINCS_LDP', 'Lonza', 'NCI-DTP', 'PRIDE', 'PRIDE', 'PRIDE', 'PRIDE', 'PRIDE', 'PRIDE', 'SKY/M-FISH/CGH', 'Wikidata']
# CosmicIDs:
# ['687936', '875874', '897461', '905947', '972929', '974305', '982276', '1044259', '1092589', '1175848', '1305372', '1312360', '1481416', '1998431', '2036676', '2520637', '2663796']
# Disease:
# ['Renal cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_EJ06']
# Names:
# ['794CSF']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1751978']
# Disease:
# ['Atypical teratoid/rhabdoid tumor']
# ---
# CellosaurusID:
# ['CVCL_S563']
# Names:
# ['798-mel', '798mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905218']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_1052']
# Names:
# ['8-MG-BA', '8MGBA']
# Databases:
# ['CLO', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687562', '1746945', '2302327', '2367505']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_1053']
# Names:
# ['8305C', '8305c', '8305-C', '8305C_1']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'ICLC', 'JCRB', 'LINCS_LDP', 'NCBI_Iran', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['906795', '922364', '2009523', '2054104', '2613247']
# Disease:
# ['Thyroid gland undifferentiated (anaplastic) carcinoma']
# ---
# CellosaurusID:
# ['CVCL_2292']
# Names:
# ['833K-E', '833KE', '833-KE', '833K', 'HT-E']
# Databases:
# ['ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'ECACC', 'Wikidata']
# CosmicIDs:
# ['821812', '2077187']
# Disease:
# ['Testicular embryonal carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1054']
# Names:
# ['8505C', '8505c']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'JCRB', 'LINCS_LDP', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['889489', '891256', '922365', '924102', '1084283', '1132598', '1152114', '1162837', '1239959', '2036694', '2054105', '2613248']
# Disease:
# ['Thyroid gland undifferentiated (anaplastic) carcinoma']
# ---
# CellosaurusID:
# ['CVCL_6757']
# Names:
# ['86-2']
# Databases:
# ['CLO', 'BioSample', 'CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['946066', '1048223', '1066157', '1656908']
# Disease:
# ['Large cell lung carcinoma']
# ---
# CellosaurusID:
# ['CVCL_S564']
# Names:
# ['865-mel', '865mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905219']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8090']
# Names:
# ['866MT', '866 MT']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['929964', '932917', '934540', '2668259']
# Disease:
# ['Non-small cell lung carcinoma']
# ---
# CellosaurusID:
# ['CVCL_S565']
# Names:
# ['883-mel', '883mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905220']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_4632']
# Names:
# ['888-mel', '888-MEL', '888 mel', '888mel', '888MEL', '888', 'Mel888', 'MG-888']
# Databases:
# ['BTO', 'EFO', 'ArrayExpress', 'CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876679', '877281', '905221', '1042621', '1238108', '1303045']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S566']
# Names:
# ['894-mel', '894mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905222']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W909']
# Names:
# ['92-1 [Human bladder carcinoma]', 'TCC 92-1']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046694', '1285106', '2037941', '2050430', '2212690']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8607']
# Names:
# ['92-1 [Human uveal melanoma]', '92_1', '92.1']
# Databases:
# ['CLDB', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'ECACC', 'ESTDAB', 'GEO', 'ICLC', 'Wikidata']
# CosmicIDs:
# ['848328', '899893', '916137', '986619', '1320371', '1628394', '1669117', '2036703', '2163829']
# Disease:
# ['Uveal melanoma']
# ---
# CellosaurusID:
# ['CVCL_C300']
# Names:
# ['92-2', '92_2', '92.2']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['916138']
# Disease:
# ['Uveal melanoma']
# ---
# CellosaurusID:
# ['CVCL_8058']
# Names:
# ['938-mel', '938-MEL', '938 mel', '938']
# Databases:
# ['BTO', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['876686']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8608']
# Names:
# ['94-10', 'TCC 94-10']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['2050431', '2057436', '2212691', '2444254']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_S567']
# Names:
# ['952-mel', '952mel']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['905224']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_8609']
# Names:
# ['96-1', 'TCC 96-1']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046700', '1285107', '2037942', '2050432', '2057437', '2444232', '2685933']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8616']
# Names:
# ['97-1', 'TCC 97-1']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046701', '1285108', '1927314', '2050433', '2057438', '2444253', '2685934']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8619']
# Names:
# ['97-18-I', 'TCC 97-18-I', 'TCC 97-18', '97-18']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046697', '2037943', '2050434', '2057440', '2444256', '2685935']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8620']
# Names:
# ['97-21-M', 'TCC 97-21-M', 'TCC 97-21', '97-21']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1046698', '1285109']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8621']
# Names:
# ['97-24', 'TCC 97-24']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046699', '1285110', '2037944', '2050435', '2057441', '2444247', '2685936']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8622']
# Names:
# ['97-29', 'TCC 97-29']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1046695']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8625']
# Names:
# ['97-7', 'TCC 97-7']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1046696', '1285111', '2050436', '2057439', '2444241', '2685937']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8481']
# Names:
# ['A-1207', 'A1207', 'A 1207']
# Databases:
# ['BTO', 'CCLE', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['2516011']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_7002']
# Names:
# ['A-1235', 'A1235']
# Databases:
# ['BTO', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1014070']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_0131']
# Names:
# ['A-172', 'A172', 'A 172', 'A-172 MG', 'A-172MG']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BioSample', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'ENCODE', 'ENCODE', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IZSLER', 'IGRhCellID', 'JCRB', 'KCB', 'KCLB', 'LINCS_LDP', 'Lonza', 'NCBI_Iran', 'PRIDE', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['687563', '849883', '897446', '1014068', '1036334', '1066233', '1171223', '1236360', '1610751', '1746956', '1995327', '2302321', '2367506', '2516012']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_9724']
# Names:
# ['A-1847', 'A1847']
# Databases:
# ['BTO', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1102822', '1175879']
# Disease:
# ['Ovarian carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1058']
# Names:
# ['A-204', 'A204']
# Databases:
# ['BTO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IGRhCellID', 'LINCS_LDP', 'Lonza', 'PRIDE', 'TOKU-E', 'Wikidata']
# CosmicIDs:
# ['687946', '802041', '910784', '1097754', '1202066', '1995328']
# Disease:
# ['Embryonal rhabdomyosarcoma']
# ---
# CellosaurusID:
# ['CVCL_1060']
# Names:
# ['A-253', 'A 253', 'A253']
# Databases:
# ['BTO', 'CLO', 'CLO', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BCRC', 'BCRJ', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'IZSLER', 'KCLB', 'LINCS_LDP', 'PRIDE', 'TOKU-E', 'Wikidata']
# CosmicIDs:
# ['688036', '906794', '921831', '1017790', '1006471', '1041671', '1995330', '2646649']
# Disease:
# ['Salivary gland squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_0132']
# Names:
# ['A-375', 'A 375', 'A375', 'A375-MEL', 'A375-mel', 'A375mel']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BCRC', 'BCRJ', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'CCRID', 'CCRID', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'ENCODE', 'ENCODE', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'IZSLER', 'KCB', 'LINCS_HMS', 'LINCS_LDP', 'Lonza', 'NCBI_Iran', 'PRIDE', 'PRIDE', 'Wikidata']
# CosmicIDs:
# ['686480', '687431', '706114', '876698', '888861', '897482', '897735', '905226', '906793', '928688', '933003', '1006556', '1022280', '1054855', '1132587', '1155278', '1211162', '1303032', '1458961', '1459655', '1477406', '1481413', '1507620', '1537486', '1555009', '1669118', '1812178', '1888914', '1890486', '1989294', '1995332', '2036699', '2230112', '2233660', '2479252']
# Disease:
# ['Amelanotic melanoma']
# ---
# CellosaurusID:
# ['CVCL_1063']
# Names:
# ['A-388', 'A388']
# Databases:
# ['CLO', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['688037', '910697', '1995333']
# Disease:
# ['Squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1055']
# Names:
# ['A-427', 'A427']
# Databases:
# ['BTO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'IZSLER', 'KCLB', 'LINCS_LDP', 'PRIDE', 'Wikidata']
# CosmicIDs:
# ['724857', '735606', '801570', '844825', '876134', '910851', '917971', '929961', '932914', '933581', '961832', '1006531', '1146870', '1218868', '1239866', '2042862', '2125175', '2668263', '2668303']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_0037']
# Names:
# ['A-431', 'A431', 'A431/P']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BCRC', 'BCRJ', 'BioSample', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IZSLER', 'JCRB', 'JCRB', 'JCRB', 'KCB', 'KCLB', 'KCLB', 'LINCS_LDP', 'Lonza', 'NCBI_Iran', 'PRIDE', 'PRIDE', 'PRIDE', 'RCB', 'RCB', 'TKG', 'TOKU-E', 'Wikidata']
# CosmicIDs:
# ['688038', '735609', '755305', '876559', '897743', '910564', '910925', '974317', '1071898', '1176624', '1351516', '1477434', '1945879', '1995334', '2131571', '2301592', '2646654']
# Disease:
# ['Vulvar squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1056']
# Names:
# ['A-498', 'A498']
# Databases:
# ['BTO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BCRC', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IGRhCellID', 'IZSLER', 'KCLB', 'LINCS_LDP', 'Lonza', 'NCI-DTP', 'PRIDE', 'PRIDE', 'SKY/M-FISH/CGH', 'TOKU-E', 'Wikidata']
# CosmicIDs:
# ['687937', '735612', '845930', '849378', '874610', '877453', '905948', '972874', '972928', '974301', '982277', '1092590', '1152531', '1175849', '1305373', '1312361', '1995335', '1998432', '2520636', '2653897', '2663797']
# Disease:
# ['Renal cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_0023', 'CVCL_H249']
# Names:
# ['A-549', 'A 549', 'A549', 'NCI-A549', 'A549/ATCC', 'A549 ATCC', 'A549ATCC', 'hA549']
# Databases:
# ['BTO', 'CLO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', '4DN', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'ATCC', 'BCRC', 'BCRJ', 'BioSample', 'BioSample', 'CCLE', 'CCLV', 'CCRID', 'CCRID', 'CCRID', 'CCRID', 'CCRID', 'CCRID', 'CGH-DB', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'ECACC', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'E ...
# CosmicIDs:
# ['713864', '716170', '719675', '735605', '755468', '801571', '844592', '844826', '875854', '876152', '877443', '889090', '905949', '910552', '910560', '914947', '917386', '917972', '929148', '929962', '932915', '961833', '974287', '1004698', '1017830', '1028950', '1047097', '1089216', '1092591', '1146871', '1152518', '1154597', '1188587', '1219057', '1239867', '1305342', '1312328', '1352406', '1434961', '1436014', '1466799', '1571729', '1600605', '1608839', '1656896', '1802312', '1870260', '1945870', '1995337', '1998433', '2036687', '2042861', '2058649', '2125176', '2301571', '2433750', '2560224', '2630410', '2647635', '2664115', '2668269', '2668304']
# Disease:
# ['Lung adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_0080']
# Names:
# ['A-673', 'A673', 'RMS 1598', 'RMS1598']
# Databases:
# ['BTO', 'CLO', 'CLO', 'EFO', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'ENCODE', 'ENCODE', 'ENCODE', 'ENCODE', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'KCLB', 'LINCS_LDP', 'Lonza', 'Wikidata']
# CosmicIDs:
# ['684052', '1091064', '1097757', '1388901', '1718108', '1995338', '2228213', '2250469', '2294580']
# Disease:
# ['Ewing sarcoma']
# ---
# CellosaurusID:
# ['CVCL_1065']
# Names:
# ['A-704', 'A.704', 'A704']
# Databases:
# ['BTO', 'CLO', 'CLO', 'CLO', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'ATCC', 'BioSample', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IZSLER', 'KCLB', 'LINCS_LDP', 'NCI-DTP', 'Wikidata']
# CosmicIDs:
# ['687938', '910920', '979707', '982279', '1995339', '2520641']
# Disease:
# ['Renal cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_W875']
# Names:
# ['A02']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['888981', '1996407']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S856']
# Names:
# ['A04-GEH', 'A04']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['928718', '1211160']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W876']
# Names:
# ['A05']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['888982', '1211161']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_S857']
# Names:
# ['A06-MLC', 'A06']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['928719', '1996408']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W879']
# Names:
# ['A07', 'A07RM', 'A07.RM']
# Databases:
# ['Cosmic', 'GEO', 'GEO', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['888983']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_E301', 'CVCL_D552']
# Names:
# ['A10.7', 'LZ10.7', 'E3LZ10.7', 'Pa03C']
# Databases:
# ['AddexBio', 'AddexBio', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1473117', '1509850']
# Disease:
# ['Pancreatic ductal adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_1057']
# Names:
# ['A101D', 'A-101D']
# Databases:
# ['CLO', 'EFO', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'GEO', 'IGRhCellID', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687429', '910921', '1155279', '1995326']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_W877']
# Names:
# ['A11 [Human melanoma]']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['888984', '1303028']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_D135']
# Names:
# ['A1165']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['735608']
# Disease:
# ['Pancreatic carcinoma']
# ---
# CellosaurusID:
# ['CVCL_W878']
# Names:
# ['A15 [Human melanoma]']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'GEO', 'Wikidata']
# CosmicIDs:
# ['888985', '1303029']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_D137']
# Names:
# ['A1663']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['735610']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_V399']
# Names:
# ['A1698', 'A-1698']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['760487']
# Disease:
# ['Bladder carcinoma']
# ---
# CellosaurusID:
# ['CVCL_E303']
# Names:
# ['A2.1', 'GS2.1', 'Pa01C']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1473030', '1509848']
# Disease:
# ['Pancreatic ductal adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_1059']
# Names:
# ['A2058', 'A 2058', 'A-2058']
# Databases:
# ['BTO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'BioSample', 'CCLE', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'eagle-i', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'JCRB', 'LINCS_LDP', 'Lonza', 'Wikidata']
# CosmicIDs:
# ['687430', '888986', '890885', '905205', '906792', '928750', '1022284', '1028799', '1054857', '1155286', '1303031', '1477415', '1481414', '1507608', '1669119', '1995329', '2159438', '2233659', '2651881']
# Disease:
# ['Amelanotic melanoma']
# ---
# CellosaurusID:
# ['CVCL_Y038']
# Names:
# ['A2095']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['687564']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_8091']
# Names:
# ['A2182', 'A-2182']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['929963', '932916', '2668260']
# Disease:
# ['Squamous cell lung carcinoma']
# ---
# CellosaurusID:
# ['CVCL_F682']
# Names:
# ['A2243', 'A-2243', 'HA2243', 'HA 2243']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1217473']
# Disease:
# ['Synovial sarcoma']
# ---
# CellosaurusID:
# ['CVCL_0134']
# Names:
# ['A2780', 'A-2780', '2780', 'A2780S']
# Databases:
# ['BTO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'BCRJ', 'BioSample', 'CCLE', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'LINCS_LDP', 'Lonza', 'MetaboLights', 'NCI-DTP', 'PRIDE', 'PRIDE', 'PRIDE', 'Wikidata', 'Ximbio']
# CosmicIDs:
# ['688090', '755844', '849607', '906804', '923108', '948284', '987394', '1102819', '1139223', '1198265', '1305309', '1609529', '1707564', '1708387', '1709251', '1945872', '1995331', '2582805', '2674698']
# Disease:
# ['Ovarian endometrioid adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_H745']
# Names:
# ['A2780-cisR', 'A2780-CISR', 'A2780/cisR', 'A2780cisR', 'A2780(cisR)']
# Databases:
# ['ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'MetaboLights', 'Wikidata']
# CosmicIDs:
# ['688091']
# Disease:
# ['Ovarian endometrioid adenocarcinoma']
# ---
# CellosaurusID:
# ...
# Disease:
# ['Oropharyngeal squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8021']
# Names:
# ['YCU-MS861', 'YCU MS861']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1136970', '1556183']
# Disease:
# ['Maxillary sinus squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8022']
# Names:
# ['YCU-OR891', 'YCU OR891']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1136962', '1556189']
# Disease:
# ['Oral cavity squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8023']
# Names:
# ['YCU-T891', 'YCU T891']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1136968', '1556188']
# Disease:
# ['Tongue squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_8024']
# Names:
# ['YCU-T892', 'YCU T892']
# Databases:
# ['Cosmic', 'Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1136969', '1556190']
# Disease:
# ['Tongue squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_E322']
# Names:
# ['YES-2', 'YES2']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['2395009']
# Disease:
# ['Esophageal squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_1795']
# Names:
# ['YH-13', 'YH']
# Databases:
# ['ArrayExpress', 'ArrayExpress', 'BioSample', 'CCLE', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'GEO', 'JCRB', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687591', '909905', '2367556']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_9919']
# Names:
# ['YK-M2']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['975313', '1281363']
# Disease:
# ['Adult acute myeloid leukemia']
# ---
# CellosaurusID:
# ['CVCL_1796']
# Names:
# ['YKG-1', 'YKG1']
# Databases:
# ['CLO', 'ArrayExpress', 'ArrayExpress', 'BioSample', 'BioSample', 'CCLE', 'CGH-DB', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'JCRB', 'LINCS_LDP', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['687592', '2367557', '2516045']
# Disease:
# ['Glioblastoma']
# ---
# CellosaurusID:
# ['CVCL_2815']
# Names:
# ['YMB-1-E', 'YMB1-E']
# Databases:
# ['BTO', 'EFO', 'ArrayExpress', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic-CLP', 'GDSC', 'GEO', 'JCRB', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['1571791']
# Disease:
# ['Invasive ductal carcinoma, not otherwise specified']
# ---
# CellosaurusID:
# ['CVCL_1927']
# Names:
# ['YNH-1']
# Databases:
# ['BioSample', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'DSMZ', 'RCB', 'Wikidata']
# CosmicIDs:
# ['787488', '975314', '996309', '998745', '1037657', '1106592', '1281364', '1295724', '2089649']
# Disease:
# ['Adult acute myeloid leukemia']
# ---
# CellosaurusID:
# ['CVCL_H194']
# Names:
# ['YOS-M']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['787509']
# Disease:
# ['Chronic myelogenous leukemia, BCR-ABL1 positive']
# ---
# CellosaurusID:
# ['CVCL_W836']
# Names:
# ['Yoshizaki']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['945373']
# Disease:
# ['Ovarian serous adenocarcinoma']
# ---
# CellosaurusID:
# ['CVCL_N819']
# Names:
# ['YOU']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1656047']
# Disease:
# ['Peritoneal malignant mesothelioma']
# ---
# CellosaurusID:
# ['CVCL_0C32']
# Names:
# ['YR-A']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2239094']
# Disease:
# ['Small cell lung carcinoma']
# ---
# CellosaurusID:
# ['CVCL_A743']
# Names:
# ['YS9;22', 'YS9:22', 'YS9-22', 'YS 9:22']
# Databases:
# ['CGH-DB', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1012129']
# Disease:
# ['Chronic myelogenous leukemia, BCR-ABL1 positive']
# ---
# CellosaurusID:
# ['CVCL_1797']
# Names:
# ['YT']
# Databases:
# ['BTO', 'CLO', 'ArrayExpress', 'BioSample', 'CCLE', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'DSMZ', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['850219', '946358', '991546', '1012130', '1524828', '1542072', '2390120']
# Disease:
# ['Natural killer cell lymphoblastic leukemia/lymphoma']
# ---
# CellosaurusID:
# ['CVCL_EJ05']
# Names:
# ['YT-1', 'YT1']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2024371']
# Disease:
# ['Natural killer cell lymphoblastic leukemia/lymphoma']
# ---
# CellosaurusID:
# ['CVCL_J515']
# Names:
# ['YUBEL']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548846']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J516']
# Names:
# ['YUBUNE']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548847']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J065']
# Names:
# ['YUCAS']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548848']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J517']
# Names:
# ['YUCHER']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548849']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J518']
# Names:
# ['YUCLAT']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548850']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J066']
# Names:
# ['YUCOT']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548851']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J541']
# Names:
# ['YUDAN3', 'YUDAN-3', 'YUDAN 3']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1020271']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J519']
# Names:
# ['YUDEW']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548880', '2439309']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G323']
# Names:
# ['YUDOSO']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548852', '2439312']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G324']
# Names:
# ['YUFIC']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548853', '2439314']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J520']
# Names:
# ['YUGASP']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548854']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI17']
# Names:
# ['YUGATOR']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439318']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J540']
# Names:
# ['YUGEK']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548886']
# Disease:
# ['Acral lentiginous melanoma']
# ---
# CellosaurusID:
# ['CVCL_A744']
# Names:
# ['YUGEN8', 'YUGEN-8', 'YUGEN 8']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197387', '1548855', '2439320']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J067']
# Names:
# ['YUGOE']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548856']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G326']
# Names:
# ['YUHEF']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548857']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J073']
# Names:
# ['YUHEIK']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548858']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J521']
# Names:
# ['YUHOIN']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548859']
# Disease:
# ['Mucosal melanoma']
# ---
# CellosaurusID:
# ['CVCL_G327']
# Names:
# ['YUHUY']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548860']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G328']
# Names:
# ['YUKIM']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548861', '2439332']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G329']
# Names:
# ['YUKOLI']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548862']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J068']
# Names:
# ['YUKSI']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548863', '2439333']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_B483']
# Names:
# ['YULAC']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197390', '1548864']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J522']
# Names:
# ['YULIN']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548879']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI19']
# Names:
# ['YULOCUS']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439338']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J523']
# Names:
# ['YULONE']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548865', '2439339']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_A745']
# Names:
# ['YUMAC']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197386', '1548866']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI20']
# Names:
# ['YUMOBER']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439344']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_B484']
# Names:
# ['Yumoto', 'YUMOTO']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['877464', '1152542']
# Disease:
# ['Cervical squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_G331']
# Names:
# ['YUMUT']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548867']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J535']
# Names:
# ['YUNIBO']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439350']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J524']
# Names:
# ['YUNIGE']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548868']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J525']
# Names:
# ['YUNUVO']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548885']
# Disease:
# ['Acral lentiginous melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI22']
# Names:
# ['YUPAC7']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439353']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J069']
# Names:
# ['YUPLA']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548869', '2439355']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI23']
# Names:
# ['YUPOM']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439356']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_B485']
# Names:
# ['YURIF']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197391', '1548870', '2013572']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_B486']
# Names:
# ['YUROB']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548871', '2439361']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J070']
# Names:
# ['YUROL']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548872', '2439364']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_A746']
# Names:
# ['YUSAC2', 'YUSAC-2', 'YUSAC 2', 'YUSAC']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197388']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J526']
# Names:
# ['YUSAN']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548873']
# Disease:
# ['Mucosal melanoma']
# ---
# CellosaurusID:
# ['CVCL_B487']
# Names:
# ['YUSIK']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548874']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI16']
# Names:
# ['YUSIPU']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439372']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_A747']
# Names:
# ['YUSIT1', 'YUSIT-1', 'YUSIT 1', 'Yusit-1', 'YUSITI', 'Yusiti', 'YUSIT']
# Databases:
# ['Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1197389', '1921229', '2439373']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_R736']
# Names:
# ['YUSIT1-B11']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1921231']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_R737']
# Names:
# ['YUSIT1-B31']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1921232']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_R738']
# Names:
# ['YUSIT1-B5']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1921230']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_G332']
# Names:
# ['YUSIV']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548875', '2439374']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J527']
# Names:
# ['YUSTE']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548876']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J528']
# Names:
# ['YUTHO']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548881']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_J071']
# Names:
# ['YUTICA']
# Databases:
# ['Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548877', '2439381']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_G333']
# Names:
# ['YUVON3', 'YUVON']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548882']
# Disease:
# ['Acral lentiginous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J530']
# Names:
# ['YUWERA']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548883']
# Disease:
# ['Acral lentiginous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J531']
# Names:
# ['YUWIM']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548878']
# Disease:
# ['Melanoma']
# ---
# CellosaurusID:
# ['CVCL_EI18']
# Names:
# ['YUZAZ']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2439392']
# Disease:
# ['Cutaneous melanoma']
# ---
# CellosaurusID:
# ['CVCL_J072']
# Names:
# ['YUZOR']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['1548884']
# Disease:
# ['Acral lentiginous melanoma']
# ---
# CellosaurusID:
# ['CVCL_IU88']
# Names:
# ['Z-119', 'Z119']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2491094']
# Disease:
# ['B acute lymphoblastic leukemia with t(9;22)(q34;q11.2) BCR-ABL1']
# ---
# CellosaurusID:
# ['CVCL_B077']
# Names:
# ['Z-138', 'Z138']
# Databases:
# ['EFO', 'ATCC', 'BioSample', 'Cosmic', 'Cosmic', 'Cosmic', 'GEO', 'Lonza', 'Wikidata']
# CosmicIDs:
# ['2078183', '2088021', '2296992']
# Disease:
# ['Mantle cell lymphoma']
# ---
# CellosaurusID:
# ['CVCL_IU89']
# Names:
# ['Z-181', 'Z181']
# Databases:
# ['Cosmic', 'Wikidata']
# CosmicIDs:
# ['2491095']
# Disease:
# ['B acute lymphoblastic leukemia with t(9;22)(q34;q11.2) BCR-ABL1']
# ---
# CellosaurusID:
# ['CVCL_D596']
# Names:
# ['ZA']
# Databases:
# ['CGH-DB', 'Cosmic', 'Cosmic', 'Cosmic', 'Wikidata']
# CosmicIDs:
# ['930337', '1046039', '1123029']
# Disease:
# ['Oral cavity squamous cell carcinoma']
# ---
# CellosaurusID:
# ['CVCL_9920']
# Names:
# ['ZK-58', 'ZK58']
# Databases:
# ['Cosmic', 'GEO', 'Wikidata']
# CosmicIDs:
# ['1529906']
# Disease:
# ['Osteosarcoma']
# ---
# CellosaurusID:
# ['CVCL_0588']
# Names:
# ['ZR-75-1', 'ZR751', 'ZR75-1', 'ZR75_1']
# Databases:
# ['BTO', 'CLO', 'EFO', 'MCCL', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'CLDB', 'AddexBio', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'BioSample', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'CLS', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'ECACC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'ICLC', 'IMGT/HLA', 'IZSLER', 'KCB', 'KCLB', 'LINCS_HMS', 'LINCS_LDP', 'PRIDE', 'RCB', 'TKG', 'Wikidata']
# CosmicIDs:
# ['687503', '755295', '871152', '877452', '894094', '904398', '934532', '944296', '979717', '991333', '997927', '1010919', '1044205', '1046930', '1047720', '1136344', '1152530', '1175836', '1287904', '1289421', '1309006', '1326279', '1571792', '1523772', '1524343', '1603229', '1609464', '2165028', '2301536', '2318372', '2361354', '2668279']
# Disease:
# ['Invasive ductal carcinoma, not otherwise specified']
# ---
# CellosaurusID:
# ['CVCL_1661']
# Names:
# ['ZR-75-30', 'ZR7530', 'ZR75-30']
# Databases:
# ['BTO', 'CLO', 'EFO', 'CLDB', 'CLDB', 'CLDB', 'ArrayExpress', 'ArrayExpress', 'ArrayExpress', 'ATCC', 'BCRC', 'BioSample', 'CCLE', 'CCRID', 'CCRID', 'CCRID', 'CCRID', 'ChEMBL-Cells', 'ChEMBL-Targets', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic', 'Cosmic-CLP', 'ECACC', 'GDSC', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_HMS', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['687504', '871160', '877444', '894095', '904399', '909907', '921977', '949194', '979716', '1046953', '1047719', '1136346', '1152523', '1287913', '1289422', '1571790', '1603230', '2165016']
# Disease:
# ['Invasive ductal carcinoma, not otherwise specified']
# ---
# CellosaurusID:
# ['CVCL_5614']
# Names:
# ['ZR-75-B', 'ZR75-B', 'ZR-75B', 'ZR-75b', 'ZR75B']
# Databases:
# ['EFO', 'Cosmic', 'Cosmic', 'GEO', 'GEO', 'GEO', 'GEO', 'LINCS_HMS', 'LINCS_LDP', 'Wikidata']
# CosmicIDs:
# ['1136345', '1176641']
# Disease:
# ['Invasive ductal carcinoma, not otherwise specified']
# ---

# %%
cosmic_lines
# Out:
#           CellosaurusID                                          CosmicIDs  \
# CVCL_D231   [CVCL_D231]                          [889083, 946049, 1066155]
# CVCL_7942   [CVCL_7942]                                   [876687, 905206]
# CVCL_4806   [CVCL_4806]                                           [721372]
# CVCL_8029   [CVCL_8029]                                           [876702]
# CVCL_VJ83   [CVCL_VJ83]                                          [2543722]
# CVCL_D856   [CVCL_D856]                                          [1731373]
# CVCL_D857   [CVCL_D857]                                          [1731374]
# CVCL_D776   [CVCL_D776]                                          [1731375]
# CVCL_D777   [CVCL_D777]                                          [1731376]
# CVCL_S745   [CVCL_S745]                                          [1890459]
# CVCL_8030   [CVCL_8030]                                   [905207, 972280]
# CVCL_8031   [CVCL_8031]                                           [876688]
# CVCL_8033   [CVCL_8033]                                           [876689]
# CVCL_8034   [CVCL_8034]                                           [876690]
# CVCL_VJ84   [CVCL_VJ84]                                          [2543723]
# CVCL_5239   [CVCL_5239]  [686410, 905861, 972275, 1155274, 1155554, 118...
# CVCL_N588   [CVCL_N588]                                          [2307723]
# CVCL_8036   [CVCL_8036]                                           [876691]
# CVCL_7943   [CVCL_7943]                          [876682, 877280, 1042622]
# CVCL_0Q73   [CVCL_0Q73]                                          [1432838]
# CVCL_8039   [CVCL_8039]                                           [876703]
# CVCL_2265   [CVCL_2265]                                          [2402466]
# CVCL_8040   [CVCL_8040]                                           [876692]
# CVCL_Z019   [CVCL_Z019]                                           [876693]
# CVCL_Z020   [CVCL_Z020]                                           [876694]
# CVCL_8041   [CVCL_8041]                                          [2163791]
# CVCL_W281   [CVCL_W281]                                          [1418452]
# CVCL_S560   [CVCL_S560]                                           [905208]
# CVCL_8042   [CVCL_8042]                                           [876704]
# CVCL_8043   [CVCL_8043]                                           [876695]
# ...                 ...                                                ...
# CVCL_J069   [CVCL_J069]                                 [1548869, 2439355]
# CVCL_EI23   [CVCL_EI23]                                          [2439356]
# CVCL_B485   [CVCL_B485]                        [1197391, 1548870, 2013572]
# CVCL_B486   [CVCL_B486]                                 [1548871, 2439361]
# CVCL_J070   [CVCL_J070]                                 [1548872, 2439364]
# CVCL_A746   [CVCL_A746]                                          [1197388]
# CVCL_J526   [CVCL_J526]                                          [1548873]
# CVCL_B487   [CVCL_B487]                                          [1548874]
# CVCL_EI16   [CVCL_EI16]                                          [2439372]
# CVCL_A747   [CVCL_A747]                        [1197389, 1921229, 2439373]
# CVCL_R736   [CVCL_R736]                                          [1921231]
# CVCL_R737   [CVCL_R737]                                          [1921232]
# CVCL_R738   [CVCL_R738]                                          [1921230]
# CVCL_G332   [CVCL_G332]                                 [1548875, 2439374]
# CVCL_J527   [CVCL_J527]                                          [1548876]
# CVCL_J528   [CVCL_J528]                                          [1548881]
# CVCL_J071   [CVCL_J071]                                 [1548877, 2439381]
# CVCL_G333   [CVCL_G333]                                          [1548882]
# CVCL_J530   [CVCL_J530]                                          [1548883]
# CVCL_J531   [CVCL_J531]                                          [1548878]
# CVCL_EI18   [CVCL_EI18]                                          [2439392]
# CVCL_J072   [CVCL_J072]                                          [1548884]
# CVCL_IU88   [CVCL_IU88]                                          [2491094]
# CVCL_B077   [CVCL_B077]                        [2078183, 2088021, 2296992]
# CVCL_IU89   [CVCL_IU89]                                          [2491095]
# CVCL_D596   [CVCL_D596]                         [930337, 1046039, 1123029]
# CVCL_9920   [CVCL_9920]                                          [1529906]
# CVCL_0588   [CVCL_0588]  [687503, 755295, 871152, 877452, 894094, 90439...
# CVCL_1661   [CVCL_1661]  [687504, 871160, 877444, 894095, 904399, 90990...
# CVCL_5614   [CVCL_5614]                                 [1136345, 1176641]
#
#                                                    Databases  \
# CVCL_D231  [ChEMBL-Cells, ChEMBL-Targets, Cosmic, Cosmic,...
# CVCL_7942                 [CGH-DB, Cosmic, Cosmic, Wikidata]
# CVCL_4806                                 [Cosmic, Wikidata]
# CVCL_8029                                 [Cosmic, Wikidata]
# CVCL_VJ83                                           [Cosmic]
# CVCL_D856                                 [Cosmic, Wikidata]
# CVCL_D857                                 [Cosmic, Wikidata]
# CVCL_D776                                 [Cosmic, Wikidata]
# CVCL_D777                                 [Cosmic, Wikidata]
# CVCL_S745                                 [Cosmic, Wikidata]
# CVCL_8030       [BTO, CGH-DB, Cosmic, Cosmic, GEO, Wikidata]
# CVCL_8031                                 [Cosmic, Wikidata]
# CVCL_8033                            [Cosmic, GEO, Wikidata]
# CVCL_8034                                 [Cosmic, Wikidata]
# CVCL_VJ84                                           [Cosmic]
# CVCL_5239  [BTO, CLO, EFO, ATCC, BioSample, Coriell, Cosm...
# CVCL_N588                                 [Cosmic, Wikidata]
# CVCL_8036                                 [Cosmic, Wikidata]
# CVCL_7943  [Cosmic, Cosmic, Cosmic, GEO, GEO, GEO, Wikidata]
# CVCL_0Q73                            [BTO, Cosmic, Wikidata]
# CVCL_8039                                 [Cosmic, Wikidata]
# CVCL_2265  [CLO, CLDB, CCRID, Cosmic, ECACC, ICLC, NCBI_I...
# CVCL_8040                                 [Cosmic, Wikidata]
# CVCL_Z019                                 [Cosmic, Wikidata]
# CVCL_Z020                                 [Cosmic, Wikidata]
# CVCL_8041                         [Cosmic, ESTDAB, Wikidata]
# CVCL_W281                                 [Cosmic, Wikidata]
# CVCL_S560                         [CGH-DB, Cosmic, Wikidata]
# CVCL_8042                                 [Cosmic, Wikidata]
# CVCL_8043                                 [Cosmic, Wikidata]
# ...                                                      ...
# CVCL_J069                         [Cosmic, Cosmic, Wikidata]
# CVCL_EI23                                 [Cosmic, Wikidata]
# CVCL_B485                 [Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_B486                         [Cosmic, Cosmic, Wikidata]
# CVCL_J070                         [Cosmic, Cosmic, Wikidata]
# CVCL_A746                                 [Cosmic, Wikidata]
# CVCL_J526                                 [Cosmic, Wikidata]
# CVCL_B487                                 [Cosmic, Wikidata]
# CVCL_EI16                                 [Cosmic, Wikidata]
# CVCL_A747                 [Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_R736                                 [Cosmic, Wikidata]
# CVCL_R737                                 [Cosmic, Wikidata]
# CVCL_R738                                 [Cosmic, Wikidata]
# CVCL_G332                         [Cosmic, Cosmic, Wikidata]
# CVCL_J527                                 [Cosmic, Wikidata]
# CVCL_J528                                 [Cosmic, Wikidata]
# CVCL_J071                         [Cosmic, Cosmic, Wikidata]
# CVCL_G333                                 [Cosmic, Wikidata]
# CVCL_J530                                 [Cosmic, Wikidata]
# CVCL_J531                                 [Cosmic, Wikidata]
# CVCL_EI18                                 [Cosmic, Wikidata]
# CVCL_J072                                 [Cosmic, Wikidata]
# CVCL_IU88                                 [Cosmic, Wikidata]
# CVCL_B077  [EFO, ATCC, BioSample, Cosmic, Cosmic, Cosmic,...
# CVCL_IU89                                 [Cosmic, Wikidata]
# CVCL_D596         [CGH-DB, Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_9920                            [Cosmic, GEO, Wikidata]
# CVCL_0588  [BTO, CLO, EFO, MCCL, CLDB, CLDB, CLDB, CLDB, ...
# CVCL_1661  [BTO, CLO, EFO, CLDB, CLDB, CLDB, ArrayExpress...
# CVCL_5614  [EFO, Cosmic, Cosmic, GEO, GEO, GEO, GEO, LINC...
#
#                                                      Disease  \
# CVCL_D231                                Lung adenocarcinoma
# CVCL_7942                                           Melanoma
# CVCL_4806                                 Prostate carcinoma
# CVCL_8029                                           Melanoma
# CVCL_VJ83                                 Cutaneous melanoma
# CVCL_D856                                Lung adenocarcinoma
# CVCL_D857                                Lung adenocarcinoma
# CVCL_D776                                Lung adenocarcinoma
# CVCL_D777                                Lung adenocarcinoma
# CVCL_S745                                Lung adenocarcinoma
# CVCL_8030                                           Melanoma
# CVCL_8031                                           Melanoma
# CVCL_8033                                           Melanoma
# CVCL_8034                                           Melanoma
# CVCL_VJ84                                 Cutaneous melanoma
# CVCL_5239                                           Melanoma
# CVCL_N588                                   Synovial sarcoma
# CVCL_8036                                           Melanoma
# CVCL_7943                                           Melanoma
# CVCL_0Q73                                      Endometriosis
# CVCL_8039                                           Melanoma
# CVCL_2265           Childhood T acute lymphoblastic leukemia
# CVCL_8040                                           Melanoma
# CVCL_Z019                                           Melanoma
# CVCL_Z020                                           Melanoma
# CVCL_8041                                           Melanoma
# CVCL_W281                                           Melanoma
# CVCL_S560                                           Melanoma
# CVCL_8042                                           Melanoma
# CVCL_8043                                           Melanoma
# ...                                                      ...
# CVCL_J069                                 Cutaneous melanoma
# CVCL_EI23                                 Cutaneous melanoma
# CVCL_B485                                 Cutaneous melanoma
# CVCL_B486                                 Cutaneous melanoma
# CVCL_J070                                 Cutaneous melanoma
# CVCL_A746                                           Melanoma
# CVCL_J526                                   Mucosal melanoma
# CVCL_B487                                 Cutaneous melanoma
# CVCL_EI16                                 Cutaneous melanoma
# CVCL_A747                                           Melanoma
# CVCL_R736                                           Melanoma
# CVCL_R737                                           Melanoma
# CVCL_R738                                           Melanoma
# CVCL_G332                                 Cutaneous melanoma
# CVCL_J527                                 Cutaneous melanoma
# CVCL_J528                                           Melanoma
# CVCL_J071                                 Cutaneous melanoma
# CVCL_G333                         Acral lentiginous melanoma
# CVCL_J530                         Acral lentiginous melanoma
# CVCL_J531                                           Melanoma
# CVCL_EI18                                 Cutaneous melanoma
# CVCL_J072                         Acral lentiginous melanoma
# CVCL_IU88  B acute lymphoblastic leukemia with t(9;22)(q3...
# CVCL_B077                               Mantle cell lymphoma
# CVCL_IU89  B acute lymphoblastic leukemia with t(9;22)(q3...
# CVCL_D596                Oral cavity squamous cell carcinoma
# CVCL_9920                                       Osteosarcoma
# CVCL_0588  Invasive ductal carcinoma, not otherwise speci...
# CVCL_1661  Invasive ductal carcinoma, not otherwise speci...
# CVCL_5614  Invasive ductal carcinoma, not otherwise speci...
#
#                                                        Names
# CVCL_D231                                             [1-87]
# CVCL_7942  [1011-mel, 1011-MEL, 1011 mel, 1011mel, 1011, ...
# CVCL_4806                                    [1013L, 1013-L]
# CVCL_8029     [1088-mel, 1088-MEL, 1088 Mel, 1088 mel, 1088]
# CVCL_VJ83                                      [10CM, 10 CM]
# CVCL_D856                         [11-18-ER1-7, 11-18/ER1-7]
# CVCL_D857                         [11-18-ER2-1, 11-18/ER2-1]
# CVCL_D776                     [11-18-GEF10-1, 11-18/GEF10-1]
# CVCL_D777                     [11-18-GEF20-1, 11-18/GEF20-1]
# CVCL_S745                        [11-18/R, 11-18R, 11-18/ER]
# CVCL_8030  [1102-mel, 1102-MEL, 1102 mel, 1102mel, 1102, ...
# CVCL_8031               [1143-mel, 1143-MEL, 1143 mel, 1143]
# CVCL_8033               [1195-mel, 1195-MEL, 1195 mel, 1195]
# CVCL_8034               [1199-mel, 1199-MEL, 1199 mel, 1199]
# CVCL_VJ84                                      [11CM, 11 CM]
# CVCL_5239  [1205Lu, 1205-Lu, 1205 Lu, WM 1205LU, WM-1205L...
# CVCL_N588                                    [1273/99, 1273]
# CVCL_8036               [1280-mel, 1280-MEL, 1280 mel, 1280]
# CVCL_7943  [1290-mel, 1290-MEL, 1290 mel, 1290, MG-1290, ...
# CVCL_0Q73                        [12Z, 12z, 12-Z, Z12, Z-12]
# CVCL_8039               [1300-mel, 1300-MEL, 1300 mel, 1300]
# CVCL_2265                                             [1301]
# CVCL_8040               [1317-mel, 1317-MEL, 1317 mel, 1317]
# CVCL_Z019                               [1335-mel, 1335-MEL]
# CVCL_Z020                               [1352-mel, 1352-MEL]
# CVCL_8041     [1359-mel, 1359-MEL, 1359 mel, 1359, Mel-1359]
# CVCL_W281                                            [136-2]
# CVCL_S560            [1362-mel, 1362-MEL, 1362 mel, 1362mel]
# CVCL_8042               [1363-mel, 1363-MEL, 1363 mel, 1363]
# CVCL_8043               [1376-mel, 1376-MEL, 1376 mel, 1376]
# ...                                                      ...
# CVCL_J069                                            [YUPLA]
# CVCL_EI23                                            [YUPOM]
# CVCL_B485                                            [YURIF]
# CVCL_B486                                            [YUROB]
# CVCL_J070                                            [YUROL]
# CVCL_A746                  [YUSAC2, YUSAC-2, YUSAC 2, YUSAC]
# CVCL_J526                                            [YUSAN]
# CVCL_B487                                            [YUSIK]
# CVCL_EI16                                           [YUSIPU]
# CVCL_A747  [YUSIT1, YUSIT-1, YUSIT 1, Yusit-1, YUSITI, Yu...
# CVCL_R736                                       [YUSIT1-B11]
# CVCL_R737                                       [YUSIT1-B31]
# CVCL_R738                                        [YUSIT1-B5]
# CVCL_G332                                            [YUSIV]
# CVCL_J527                                            [YUSTE]
# CVCL_J528                                            [YUTHO]
# CVCL_J071                                           [YUTICA]
# CVCL_G333                                    [YUVON3, YUVON]
# CVCL_J530                                           [YUWERA]
# CVCL_J531                                            [YUWIM]
# CVCL_EI18                                            [YUZAZ]
# CVCL_J072                                            [YUZOR]
# CVCL_IU88                                      [Z-119, Z119]
# CVCL_B077                                      [Z-138, Z138]
# CVCL_IU89                                      [Z-181, Z181]
# CVCL_D596                                               [ZA]
# CVCL_9920                                      [ZK-58, ZK58]
# CVCL_0588                   [ZR-75-1, ZR751, ZR75-1, ZR75_1]
# CVCL_1661                        [ZR-75-30, ZR7530, ZR75-30]
# CVCL_5614           [ZR-75-B, ZR75-B, ZR-75B, ZR-75b, ZR75B]
#
# [4752 rows x 5 columns]

# %%
print("done")
# Out:
# done

# %%
pickle.dump(cosmic_lines, file=open('data/raw/cellosaurus/cellosaurus_cosmic_cell_lines.p','wb'))
pickle.dump(all_lines, file=open('data/raw/cellosaurus/cellosaurus_all_cell_lines.p','wb'))

# %%
cosmic_lines = pickle.load(file=open('data/raw/cellosaurus/cellosaurus_cosmic_cell_lines.p','rb'))
all_lines = pickle.load(file=open('data/raw/cellosaurus/cellosaurus_all_cell_lines.p','rb'))

# %% [markdown]
# ## Assuming that DiSCoVER has finished

# %%
# cosmic_lines['CosmicIDs'] = cosmic_lines['CosmicIDs'].apply(lambda x:list(map(int, x)))

# %%
compilation = []
for temp in cosmic_lines['CosmicIDs']:
    for j in temp:
#         compilation.append(int(j))
        compilation.append(j)

# %%
compilation
# Out:
# [889083,
#  946049,
#  1066155,
#  876687,
#  905206,
#  721372,
#  876702,
#  2543722,
#  1731373,
#  1731374,
#  1731375,
#  1731376,
#  1890459,
#  905207,
#  972280,
#  876688,
#  876689,
#  876690,
#  2543723,
#  686410,
#  905861,
#  972275,
#  1155274,
#  1155554,
#  1187583,
#  1303026,
#  1507616,
#  2307723,
#  876691,
#  876682,
#  877280,
#  1042622,
#  1432838,
#  876703,
#  2402466,
#  876692,
#  876693,
#  876694,
#  2163791,
#  1418452,
#  905208,
#  876704,
#  876695,
#  876696,
#  876697,
#  2077184,
#  2439937,
#  1074398,
#  1529910,
#  2009541,
#  2163792,
#  2362659,
#  2163759,
#  1716565,
#  1672268,
#  2307720,
#  2077189,
#  2439938,
#  802250,
#  2361370,
#  1042624,
#  1042625,
#  1105000,
#  1105010,
#  1042626,
#  2037945,
#  802248,
#  948294,
#  1479983,
#  910550,
#  2077185,
#  2163762,
#  2163760,
#  2163761,
#  924100,
#  1075276,
#  1028699,
#  1071480,
#  1172629,
#  1330911,
#  1689707,
#  1995323,
#  2537791,
#  2580126,
#  2651766,
#  2669170,
#  910924,
#  1995324,
#  2484956,
#  715794,
#  760476,
#  845564,
#  925827,
#  928820,
#  1016884,
#  1046680,
#  1082644,
#  1938694,
#  1285102,
#  1285997,
#  1927305,
#  2050426,
#  2057433,
#  2444255,
#  2685929,
#  2700994,
#  846282,
#  1082645,
#  1938695,
#  910551,
#  2163757,
#  887218,
#  924101,
#  1012056,
#  1130253,
#  1524787,
#  876699,
#  905209,
#  897736,
#  1295344,
#  1058336,
#  1105011,
#  1672267,
#  2307719,
#  1609533,
#  688088,
#  1609530,
#  687561,
#  1746946,
#  1995325,
#  2060804,
#  2302328,
#  686411,
#  1047656,
#  1155281,
#  1155568,
#  1187587,
#  1303027,
#  2163808,
#  2230114,
#  1322951,
#  1459415,
#  1459416,
#  686481,
#  876680,
#  905210,
#  1197392,
#  1238106,
#  1458962,
#  1559440,
#  2159451,
#  2163827,
#  2440478,
#  905211,
#  1303043,
#  876685,
#  905212,
#  1507618,
#  2233664,
#  905213,
#  687452,
#  715695,
#  760484,
#  845565,
#  846281,
#  928819,
#  943732,
#  1016892,
#  1046675,
#  1093983,
#  1285103,
#  1285998,
#  1927307,
#  2050427,
#  2057434,
#  2301520,
#  2444227,
#  2685930,
#  2700995,
#  1016885,
#  876700,
#  2727474,
#  1609532,
#  2366878,
#  997932,
#  1000128,
#  1046948,
#  1091346,
#  1136351,
#  1176628,
#  1287907,
#  1289403,
#  2301521,
#  876683,
#  905214,
#  1303044,
#  1559441,
#  2163793,
#  906798,
#  923375,
#  928821,
#  1285104,
#  1927315,
#  2050428,
#  2685931,
#  906797,
#  928822,
#  1046676,
#  1285105,
#  1286005,
#  1927309,
#  2050429,
#  2057435,
#  2444239,
#  2685932,
#  1078384,
#  1082508,
#  1718435,
#  2228212,
#  906800,
#  1037742,
#  1130252,
#  1191693,
#  1524788,
#  2396142,
#  2427693,
#  2649230,
#  905215,
#  905216,
#  905217,
#  687935,
#  801355,
#  910922,
#  982280,
#  1779197,
#  2520640,
#  687936,
#  875874,
#  897461,
#  905947,
#  972929,
#  974305,
#  982276,
#  1044259,
#  1092589,
#  1175848,
#  1305372,
#  1312360,
#  1481416,
#  1998431,
#  2036676,
#  2520637,
#  2663796,
#  1751978,
#  905218,
#  687562,
#  1746945,
#  2302327,
#  2367505,
#  906795,
#  922364,
#  2009523,
#  2054104,
#  2613247,
#  821812,
#  2077187,
#  889489,
#  891256,
#  922365,
#  924102,
#  1084283,
#  1132598,
#  1152114,
#  1162837,
#  1239959,
#  2036694,
#  2054105,
#  2613248,
#  946066,
#  1048223,
#  1066157,
#  1656908,
#  905219,
#  929964,
#  932917,
#  934540,
#  2668259,
#  905220,
#  876679,
#  877281,
#  905221,
#  1042621,
#  1238108,
#  1303045,
#  905222,
#  1046694,
#  1285106,
#  2037941,
#  2050430,
#  2212690,
#  848328,
#  899893,
#  916137,
#  986619,
#  1320371,
#  1628394,
#  1669117,
#  2036703,
#  2163829,
#  916138,
#  876686,
#  2050431,
#  2057436,
#  2212691,
#  2444254,
#  905224,
#  1046700,
#  1285107,
#  2037942,
#  2050432,
#  2057437,
#  2444232,
#  2685933,
#  1046701,
#  1285108,
#  1927314,
#  2050433,
#  2057438,
#  2444253,
#  2685934,
#  1046697,
#  2037943,
#  2050434,
#  2057440,
#  2444256,
#  2685935,
#  1046698,
#  1285109,
#  1046699,
#  1285110,
#  2037944,
#  2050435,
#  2057441,
#  2444247,
#  2685936,
#  1046695,
#  1046696,
#  1285111,
#  2050436,
#  2057439,
#  2444241,
#  2685937,
#  2516011,
#  1014070,
#  687563,
#  849883,
#  897446,
#  1014068,
#  1036334,
#  1066233,
#  1171223,
#  1236360,
#  1610751,
#  1746956,
#  1995327,
#  2302321,
#  2367506,
#  2516012,
#  1102822,
#  1175879,
#  687946,
#  802041,
#  910784,
#  1097754,
#  1202066,
#  1995328,
#  688036,
#  906794,
#  921831,
#  1017790,
#  1006471,
#  1041671,
#  1995330,
#  2646649,
#  686480,
#  687431,
#  706114,
#  876698,
#  888861,
#  897482,
#  897735,
#  905226,
#  906793,
#  928688,
#  933003,
#  1006556,
#  1022280,
#  1054855,
#  1132587,
#  1155278,
#  1211162,
#  1303032,
#  1458961,
#  1459655,
#  1477406,
#  1481413,
#  1507620,
#  1537486,
#  1555009,
#  1669118,
#  1812178,
#  1888914,
#  1890486,
#  1989294,
#  1995332,
#  2036699,
#  2230112,
#  2233660,
#  2479252,
#  688037,
#  910697,
#  1995333,
#  724857,
#  735606,
#  801570,
#  844825,
#  876134,
#  910851,
#  917971,
#  929961,
#  932914,
#  933581,
#  961832,
#  1006531,
#  1146870,
#  1218868,
#  1239866,
#  2042862,
#  2125175,
#  2668263,
#  2668303,
#  688038,
#  735609,
#  755305,
#  876559,
#  897743,
#  910564,
#  910925,
#  974317,
#  1071898,
#  1176624,
#  1351516,
#  1477434,
#  1945879,
#  1995334,
#  2131571,
#  2301592,
#  2646654,
#  687937,
#  735612,
#  845930,
#  849378,
#  874610,
#  877453,
#  905948,
#  972874,
#  972928,
#  974301,
#  982277,
#  1092590,
#  1152531,
#  1175849,
#  1305373,
#  1312361,
#  1995335,
#  1998432,
#  2520636,
#  2653897,
#  2663797,
#  713864,
#  716170,
#  719675,
#  735605,
#  755468,
#  801571,
#  844592,
#  844826,
#  875854,
#  876152,
#  877443,
#  889090,
#  905949,
#  910552,
#  910560,
#  914947,
#  917386,
#  917972,
#  929148,
#  929962,
#  932915,
#  961833,
#  974287,
#  1004698,
#  1017830,
#  1028950,
#  1047097,
#  1089216,
#  1092591,
#  1146871,
#  1152518,
#  1154597,
#  1188587,
#  1219057,
#  1239867,
#  1305342,
#  1312328,
#  1352406,
#  1434961,
#  1436014,
#  1466799,
#  1571729,
#  1600605,
#  1608839,
#  1656896,
#  1802312,
#  1870260,
#  1945870,
#  1995337,
#  1998433,
#  2036687,
#  2042861,
#  2058649,
#  2125176,
#  2301571,
#  2433750,
#  2560224,
#  2630410,
#  2647635,
#  2664115,
#  2668269,
#  2668304,
#  684052,
#  1091064,
#  1097757,
#  1388901,
#  1718108,
#  1995338,
#  2228213,
#  2250469,
#  2294580,
#  687938,
#  910920,
#  979707,
#  982279,
#  1995339,
#  2520641,
#  888981,
#  1996407,
#  928718,
#  1211160,
#  888982,
#  1211161,
#  928719,
#  1996408,
#  888983,
#  1473117,
#  1509850,
#  687429,
#  910921,
#  1155279,
#  1995326,
#  888984,
#  1303028,
#  735608,
#  888985,
#  1303029,
#  735610,
#  760487,
#  1473030,
#  1509848,
#  687430,
#  888986,
#  890885,
#  905205,
#  906792,
#  928750,
#  1022284,
#  1028799,
#  1054857,
#  1155286,
#  1303031,
#  1477415,
#  1481414,
#  1507608,
#  1669119,
#  1995329,
#  2159438,
#  2233659,
#  2651881,
#  687564,
#  929963,
#  932916,
#  2668260,
#  1217473,
#  688090,
#  755844,
#  849607,
#  906804,
#  923108,
#  948284,
#  987394,
#  1102819,
#  1139223,
#  1198265,
#  1305309,
#  1609529,
#  1707564,
#  1708387,
#  1709251,
#  1945872,
#  1995331,
#  2582805,
#  2674698,
#  688091,
#  1139224,
#  910935,
#  919153,
#  1473089,
#  1509853,
#  1890494,
#  1890487,
#  1890495,
#  1890488,
#  1890489,
#  1890491,
#  1890492,
#  1890490,
#  1890493,
#  932715,
#  932714,
#  1045406,
#  1067223,
#  1238110,
#  932716,
#  1238111,
#  1303033,
#  1473125,
#  1509854,
#  910934,
#  998704,
#  1037706,
#  1995336,
#  1718428,
#  2060798,
#  933523,
#  1477307,
#  1509878,
#  1473116,
#  1509849,
#  736266,
#  808169,
#  933524,
#  710850,
#  736267,
#  808168,
#  933525,
#  1108342,
#  1320466,
#  736268,
#  933526,
#  1767220,
#  801582,
#  876153,
#  906791,
#  917991,
#  946050,
#  1066158,
#  1154598,
#  1239868,
#  1571728,
#  2125217,
#  2668323,
#  932295,
#  934437,
#  934438,
#  934472,
#  1089237,
#  934433,
#  934454,
#  934456,
#  1089226,
#  934440,
#  934441,
#  934458,
#  934459,
#  1089222,
#  2647636,
#  934443,
#  934461,
#  934444,
#  934413,
#  934415,
#  934417,
#  1089234,
#  934420,
#  1089235,
#  934412,
#  934418,
#  934422,
#  934424,
#  934426,
#  934446,
#  934447,
#  934428,
#  934430,
#  1089236,
#  934432,
#  934449,
#  2647638,
#  934451,
#  934453,
#  1089221,
#  934435,
#  877273,
#  1481540,
#  877274,
#  1481541,
#  687939,
#  849382,
#  875873,
#  877456,
#  897462,
#  905950,
#  974302,
#  979708,
#  982275,
#  1044260,
#  1092592,
#  1152534,
#  1175850,
#  1305374,
#  1312362,
#  1436045,
#  1998434,
#  2520631,
#  1622889,
#  1622905,
#  1622891,
#  1622882,
#  1622883,
#  1622884,
#  1622885,
#  1622886,
#  1622887,
#  1622907,
#  1622888,
#  906803,
#  1152115,
#  1239968,
#  2054109,
#  2239082,
#  928732,
#  1070696,
#  1071879,
#  1176601,
#  931115,
#  2228214,
#  685586,
#  848149,
#  868235,
#  873708,
#  887255,
#  888819,
#  906790,
#  1067211,
#  1090463,
#  1187266,
#  1294957,
#  1482073,
#  1518239,
#  1582429,
#  1627261,
#  1995340,
#  2036659,
#  2069770,
#  2484954,
#  2664116,
#  931094,
#  2301567,
#  2162535,
#  931113,
#  711270,
#  887234,
#  1479575,
#  1218871,
#  2348804,
#  910944,
#  721715,
#  913404,
#  933537,
#  996306,
#  998724,
#  1037687,
#  1115585,
#  1175126,
#  1224372,
#  1330498,
#  1524789,
#  1641391,
#  1664519,
#  1760517,
#  2165718,
#  2602907,
#  889538,
#  889539,
#  889537,
#  902792,
#  2163016,
#  2209114,
#  685873,
#  910933,
#  1746962,
#  2302334,
#  2367507,
#  2516013,
#  1109110,
#  1543773,
#  724816,
#  787420,
#  949089,
#  975238,
#  1012057,
#  1281305,
#  2306199,
#  975237,
#  1281304,
#  1483074,
#  1889514,
#  2131561,
#  2391800,
#  687550,
#  699283,
#  713473,
#  713495,
#  809134,
#  846176,
#  871551,
#  889116,
#  910781,
#  980634,
#  1007162,
#  1057760,
#  1066221,
#  1070810,
#  1102376,
#  1105620,
#  1177683,
#  1223484,
#  1434192,
#  1576450,
#  1622894,
#  1696752,
#  2030460,
#  2646618,
#  2393013,
#  720790,
#  1170891,
#  2081377,
#  2367285,
#  1012058,
#  848245,
#  787490,
#  1026575,
#  2364007,
#  801734,
#  759914,
#  886086,
#  888020,
#  906765,
#  919148,
#  999792,
#  720774,
#  760398,
#  2302413,
#  2367270,
#  685603,
#  755291,
#  849972,
#  886550,
#  888094,
#  888277,
#  891254,
#  913250,
#  918184,
#  931242,
#  990532,
#  1005458,
#  1094760,
#  1152116,
#  1155329,
#  1162836,
#  1184761,
#  1699417,
#  2050371,
#  2367264,
#  787421,
#  975239,
#  1012059,
#  1281306,
#  2306200,
#  1515198,
#  2566118,
#  945372,
#  2054110,
#  707247,
#  710851,
#  724645,
#  808166,
#  868239,
#  872994,
#  910702,
#  913308,
#  918050,
#  922255,
#  923164,
#  932514,
#  933515,
#  947398,
#  948371,
#  948740,
#  949230,
#  1006364,
#  1090374,
#  1108341,
#  1198210,
#  1320465,
#  1366285,
#  1477433,
#  1571783,
#  1644318,
#  1995341,
#  2434085,
#  2668289,
#  1333043,
#  910687,
#  687462,
#  910704,
#  1136358,
#  1176652,
#  1309002,
#  1995342,
#  2165002,
#  966783,
#  1071907,
#  1176607,
#  877047,
#  889108,
#  918495,
#  1066228,
#  1077281,
#  1187267,
#  1482080,
#  1518246,
#  2484969,
#  873709,
#  888822,
#  1122337,
#  1187268,
#  1518243,
#  755292,
#  849970,
#  924104,
#  928836,
#  931241,
#  1084279,
#  1162847,
#  1237447,
#  1239965,
#  1280047,
#  1507369,
#  1533552,
#  1536122,
#  1889007,
#  2036692,
#  2054086,
#  2319847,
#  2613253,
#  1037743,
#  1524791,
#  2393012,
#  911904,
#  2367508,
#  1513406,
#  928723,
#  996305,
#  998722,
#  1037705,
#  910705,
#  919134,
#  999755,
#  ...]

# %%
case_id = "DMB006"
setup = pickle.load(file=open(os.path.join('patients',case_id,case_id+'_backup4_DISCoVER.p'),'rb'))

# %%
cosmic_lines.head()
# Out:
#           CellosaurusID                  CosmicIDs  \
# CVCL_D231   [CVCL_D231]  [889083, 946049, 1066155]
# CVCL_7942   [CVCL_7942]           [876687, 905206]
# CVCL_4806   [CVCL_4806]                   [721372]
# CVCL_8029   [CVCL_8029]                   [876702]
# CVCL_VJ83   [CVCL_VJ83]                  [2543722]
#
#                                                    Databases  \
# CVCL_D231  [ChEMBL-Cells, ChEMBL-Targets, Cosmic, Cosmic,...
# CVCL_7942                 [CGH-DB, Cosmic, Cosmic, Wikidata]
# CVCL_4806                                 [Cosmic, Wikidata]
# CVCL_8029                                 [Cosmic, Wikidata]
# CVCL_VJ83                                           [Cosmic]
#
#                        Disease  \
# CVCL_D231  Lung adenocarcinoma
# CVCL_7942             Melanoma
# CVCL_4806   Prostate carcinoma
# CVCL_8029             Melanoma
# CVCL_VJ83   Cutaneous melanoma
#
#                                                        Names
# CVCL_D231                                             [1-87]
# CVCL_7942  [1011-mel, 1011-MEL, 1011 mel, 1011mel, 1011, ...
# CVCL_4806                                    [1013L, 1013-L]
# CVCL_8029     [1088-mel, 1088-MEL, 1088 Mel, 1088 mel, 1088]
# CVCL_VJ83                                      [10CM, 10 CM]

# %%
import re

def disease_from_cid(what,df):
    to_return = None
    for ix,row in df.iterrows():
        temp_cids_int = [int(i) for i in row['CosmicIDs']]
        if what in temp_cids_int:
            to_return = ix
    final_dic = {}
    final_dic['Name'] = df.loc[to_return,'Names'][0]
    final_dic['Disease'] = df.loc[to_return,'Disease']
    final_dic['CellosaurusID'] = df.loc[to_return,'CellosaurusID'][0]
    return final_dic


def disease_from_name(what,df):
    to_return = None
    missing = True
    for ix,row in df.iterrows():
        # remove special characters
        new_what = simplify(what)
        new_row = simplify(row['Names'],is_list=True)
        if new_what in new_row:
            to_return = ix
            missing = False
    if missing:
        final_dic = {}
        final_dic['Name'] = what
        final_dic['Disease'] = 'Not found'
        final_dic['CellosaurusID'] = 'not_found'
    else:
        final_dic = {}
        final_dic['Name'] = df.loc[to_return,'Names'][0]
        final_dic['Disease'] = df.loc[to_return,'Disease']
        final_dic['CellosaurusID'] = df.loc[to_return,'CellosaurusID'][0]
    return final_dic
    

def simplify(what, is_list=False):
    if is_list:
        new_what = [re.sub(r'\W+', '', i) for i in what]
    else:
        # This keeps only alphanumeric charactes : https://stackoverflow.com/questions/1276764/stripping-everything-but-alphanumeric-chars-from-a-string-in-python
        new_what = re.sub(r'\W+', '', what)
    return new_what

# %%
# Make a dictionary of all the possible names

# %%
cosids
# Out:
#                   DMB006  COSMIC ID
# cosmic_688022  -0.034210     688022
# cosmic_688031  -0.064047     688031
# cosmic_713899  -0.093835     713899
# cosmic_908483  -0.093850     908483
# cosmic_753582  -0.103481     753582
# cosmic_910691  -0.110939     910691
# cosmic_924241  -0.125118     924241
# cosmic_687997  -0.126219     687997
# cosmic_753588  -0.127161     753588
# cosmic_688006  -0.127817     688006
# cosmic_949175  -0.129562     949175
# cosmic_909194  -0.129646     909194
# cosmic_753589  -0.132287     753589
# cosmic_688014  -0.144447     688014
# cosmic_688026  -0.151931     688026
# cosmic_688021  -0.154686     688021
# cosmic_687985  -0.154709     687985
# cosmic_688027  -0.156665     688027
# cosmic_688013  -0.162375     688013
# cosmic_713878  -0.162933     713878
# cosmic_688010  -0.165622     688010
# cosmic_907170  -0.167985     907170
# cosmic_910937  -0.171279     910937
# cosmic_753564  -0.175676     753564
# cosmic_713885  -0.175685     713885
# cosmic_688023  -0.177485     688023
# cosmic_1330972 -0.177860    1330972
# cosmic_687980  -0.178854     687980
# cosmic_753599  -0.178977     753599
# cosmic_908468  -0.181908     908468
# ...                  ...        ...
# cosmic_909750  -0.430866     909750
# cosmic_910697  -0.431225     910697
# cosmic_1290806 -0.431343    1290806
# cosmic_1298526 -0.431750    1298526
# cosmic_925343  -0.432826     925343
# cosmic_724869  -0.432839     724869
# cosmic_946373  -0.433100     946373
# cosmic_1298141 -0.433121    1298141
# cosmic_925347  -0.433810     925347
# cosmic_908158  -0.433884     908158
# cosmic_1240151 -0.434008    1240151
# cosmic_907065  -0.434485     907065
# cosmic_1330948 -0.434505    1330948
# cosmic_753570  -0.435582     753570
# cosmic_1240166 -0.435983    1240166
# cosmic_908156  -0.436839     908156
# cosmic_905973  -0.437390     905973
# cosmic_753532  -0.437402     753532
# cosmic_1298529 -0.439403    1298529
# cosmic_909904  -0.439583     909904
# cosmic_1298357 -0.440610    1298357
# cosmic_907285  -0.440707     907285
# cosmic_906870  -0.440755     906870
# cosmic_1290908 -0.442561    1290908
# cosmic_907279  -0.443991     907279
# cosmic_910401  -0.444065     910401
# cosmic_1240184 -0.444700    1240184
# cosmic_910702  -0.445296     910702
# cosmic_909709  -0.452093     909709
# cosmic_905938  -0.453866     905938
#
# [985 rows x 2 columns]

# %%
cosids = pd.read_csv(os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_COSMIC_IDS_gdsc.csv"),index_col=0)

for ix, row in cosids.iterrows():
#     print('---')
    cid = int(row['COSMIC ID'])
#     print(cid)
    if cid in compilation:
        dic = disease_from_cid(cid,cosmic_lines)
        cosids.loc[ix,'Name'] = dic['Name']
        cosids.at[ix,'Disease'] = dic['Disease']
        cosids.loc[ix,'CellosaurusID'] = dic['CellosaurusID']

# %%
cosids.to_excel(os.path.join(setup.discover_out_dir,"processed_cell_lines_info_gdsc.xlsx"))

# %%
cosids
# Out:
#                   DMB006  COSMIC ID            Name  \
# cosmic_688022  -0.034210     688022        NCI-H378
# cosmic_688031  -0.064047     688031         NCI-H82
# cosmic_713899  -0.093835     713899          Lu-135
# cosmic_908483  -0.093850     908483        NCI-H524
# cosmic_753582  -0.103481     753582      LB647-SCLC
# cosmic_910691  -0.110939     910691        COLO 684
# cosmic_924241  -0.125118     924241        NCI-H250
# cosmic_687997  -0.126219     687997       NCI-H1092
# cosmic_753588  -0.127161     753588        Lu-134-A
# cosmic_688006  -0.127817     688006       NCI-H1694
# cosmic_949175  -0.129562     949175         SJNB-17
# cosmic_909194  -0.129646     909194        NCI-H748
# cosmic_753589  -0.132287     753589          Lu-165
# cosmic_688014  -0.144447     688014       NCI-H2141
# cosmic_688026  -0.151931     688026         NCI-H64
# cosmic_688021  -0.154686     688021        NCI-H345
# cosmic_687985  -0.154709     687985         DMS 273
# cosmic_688027  -0.156665     688027         NCI-H69
# cosmic_688013  -0.162375     688013        NCI-H209
# cosmic_713878  -0.162933     713878          Lu-139
# cosmic_688010  -0.165622     688010       NCI-H1963
# cosmic_907170  -0.167985     907170           IMR-5
# cosmic_910937  -0.171279     910937        COR-L279
# cosmic_753564  -0.175676     753564         IST-SL1
# cosmic_713885  -0.175685     713885           SBC-1
# cosmic_688023  -0.177485     688023        NCI-H446
# cosmic_1330972 -0.177860    1330972             NaN
# cosmic_687980  -0.178854     687980        COR-L311
# cosmic_753599  -0.178977     753599       NCI-H1304
# cosmic_908468  -0.181908     908468       NCI-H1105
# ...                  ...        ...             ...
# cosmic_909750  -0.430866     909750          SW1783
# cosmic_910697  -0.431225     910697           A-388
# cosmic_1290806 -0.431343    1290806             NaN
# cosmic_1298526 -0.431750    1298526             NaN
# cosmic_925343  -0.432826     925343         MFH-ino
# cosmic_724869  -0.432839     724869         HPAF-II
# cosmic_946373  -0.433100     946373         D-502MG
# cosmic_1298141 -0.433121    1298141             NaN
# cosmic_925347  -0.433810     925347      Panc 08.13
# cosmic_908158  -0.433884     908158          NALM-6
# cosmic_1240151 -0.434008    1240151             NaN
# cosmic_907065  -0.434485     907065         HT-1197
# cosmic_1330948 -0.434505    1330948             NaN
# cosmic_753570  -0.435582     753570          KOSC-2
# cosmic_1240166 -0.435983    1240166             NaN
# cosmic_908156  -0.436839     908156          MV4-11
# cosmic_905973  -0.437390     905973          HOP-92
# cosmic_753532  -0.437402     753532        BB49-HNC
# cosmic_1298529 -0.439403    1298529             NaN
# cosmic_909904  -0.439583     909904            YAPC
# cosmic_1298357 -0.440610    1298357             NaN
# cosmic_907285  -0.440707     907285          HuP-T3
# cosmic_906870  -0.440755     906870           GDM-1
# cosmic_1290908 -0.442561    1290908             NaN
# cosmic_907279  -0.443991     907279         KINGS-1
# cosmic_910401  -0.444065     910401  Ramos.2G6.4C10
# cosmic_1240184 -0.444700    1240184             NaN
# cosmic_910702  -0.445296     910702          AsPC-1
# cosmic_909709  -0.452093     909709           SCC-9
# cosmic_905938  -0.453866     905938           HL-60
#
#                                               Disease CellosaurusID
# cosmic_688022               Small cell lung carcinoma     CVCL_1560
# cosmic_688031               Small cell lung carcinoma     CVCL_1591
# cosmic_713899               Small cell lung carcinoma     CVCL_1389
# cosmic_908483               Small cell lung carcinoma     CVCL_1568
# cosmic_753582               Small cell lung carcinoma     CVCL_1368
# cosmic_910691              Endometrial adenocarcinoma     CVCL_1132
# cosmic_924241               Small cell lung carcinoma     CVCL_1554
# cosmic_687997               Small cell lung carcinoma     CVCL_1454
# cosmic_753588               Small cell lung carcinoma     CVCL_1387
# cosmic_688006               Small cell lung carcinoma     CVCL_1489
# cosmic_949175                           Neuroblastoma     CVCL_1445
# cosmic_909194               Small cell lung carcinoma     CVCL_1588
# cosmic_753589               Small cell lung carcinoma     CVCL_1391
# cosmic_688014               Small cell lung carcinoma     CVCL_1534
# cosmic_688026               Small cell lung carcinoma     CVCL_1573
# cosmic_688021               Small cell lung carcinoma     CVCL_1558
# cosmic_687985               Small cell lung carcinoma     CVCL_1176
# cosmic_688027               Small cell lung carcinoma     CVCL_1579
# cosmic_688013               Small cell lung carcinoma     CVCL_1525
# cosmic_713878               Small cell lung carcinoma     CVCL_1390
# cosmic_688010               Small cell lung carcinoma     CVCL_1510
# cosmic_907170                           Neuroblastoma     CVCL_1306
# cosmic_910937               Small cell lung carcinoma     CVCL_1140
# cosmic_753564               Small cell lung carcinoma     CVCL_1313
# cosmic_713885               Small cell lung carcinoma     CVCL_1676
# cosmic_688023               Small cell lung carcinoma     CVCL_1562
# cosmic_1330972                                    NaN           NaN
# cosmic_687980               Small cell lung carcinoma     CVCL_2412
# cosmic_753599               Small cell lung carcinoma     CVCL_1462
# cosmic_908468               Small cell lung carcinoma     CVCL_1455
# ...                                               ...           ...
# cosmic_909750                  Anaplastic astrocytoma     CVCL_1722
# cosmic_910697                 Squamous cell carcinoma     CVCL_1063
# cosmic_1290806                                    NaN           NaN
# cosmic_1298526                                    NaN           NaN
# cosmic_925343    Undifferentiated pleomorphic sarcoma     CVCL_1407
# cosmic_724869        Pancreatic ductal adenocarcinoma     CVCL_0313
# cosmic_946373                            Glioblastoma     CVCL_1162
# cosmic_1298141                                    NaN           NaN
# cosmic_925347        Pancreatic ductal adenocarcinoma     CVCL_1638
# cosmic_908158    Adult B acute lymphoblastic leukemia     CVCL_0092
# cosmic_1240151                                    NaN           NaN
# cosmic_907065             Recurrent bladder carcinoma     CVCL_1291
# cosmic_1330948                                    NaN           NaN
# cosmic_753570   Head and neck squamous cell carcinoma     CVCL_1337
# cosmic_1240166                                    NaN           NaN
# cosmic_908156      Childhood acute monocytic leukemia     CVCL_0064
# cosmic_905973           Non-small cell lung carcinoma     CVCL_1286
# cosmic_753532   Head and neck squamous cell carcinoma     CVCL_1077
# cosmic_1298529                                    NaN           NaN
# cosmic_909904                    Pancreatic carcinoma     CVCL_1794
# cosmic_1298357                                    NaN           NaN
# cosmic_907285               Pancreatic adenocarcinoma     CVCL_1299
# cosmic_906870            Adult acute myeloid leukemia     CVCL_1230
# cosmic_1290908                                    NaN           NaN
# cosmic_907279                  Anaplastic astrocytoma     CVCL_1328
# cosmic_910401                        Burkitt lymphoma     CVCL_1646
# cosmic_1240184                                    NaN           NaN
# cosmic_910702        Pancreatic ductal adenocarcinoma     CVCL_0152
# cosmic_909709          Tongue squamous cell carcinoma     CVCL_1685
# cosmic_905938            Adult acute myeloid leukemia     CVCL_0002
#
# [985 rows x 5 columns]

# %%
# Need to save the cosids dataframe

# %%
ccle = pd.read_csv(os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_ccle.csv"),index_col=0)

ccle
# Out:
#              DMB006
# NCIH1184   0.323423
# NCIH1092   0.302924
# NCIH1155   0.255616
# NCIH1694   0.237658
# NCIH1341   0.213815
# NCIH810    0.204059
# IMR32      0.197496
# DMS114     0.190738
# DU145      0.182297
# MFE280     0.157549
# KYSE450    0.157517
# KNS62      0.155248
# NCIH2052   0.154903
# NCIH661    0.154395
# SIMA       0.154303
# 5637       0.152333
# SKNFI      0.151620
# NCIH522    0.150442
# KELLY      0.150134
# QGP1       0.146732
# SKNDZ      0.141480
# SKNSH      0.138852
# KPNSI9S    0.137589
# SUIT2      0.133746
# NCIH1651   0.132209
# NCIH211    0.131558
# NCIH2170   0.129975
# NCIH1299   0.128637
# DAOY       0.128576
# SKNBE2     0.128135
# ...             ...
# SNU1      -0.021676
# SNGM      -0.022155
# RAJI      -0.023657
# EB1       -0.024109
# OCUM1     -0.024237
# NCIH2009  -0.024563
# NCIH3255  -0.024718
# MDAMB435S -0.025119
# KU812     -0.025808
# KG1       -0.028189
# PC14      -0.028591
# PANC0203  -0.029725
# HEC151    -0.030035
# NCIH441   -0.031598
# NCIH1915  -0.031804
# KP3       -0.032378
# SKCO1     -0.032464
# PATU8902  -0.033678
# HEC265    -0.034960
# HT1376    -0.035690
# HEC6      -0.036313
# F36P      -0.036324
# KYSE30    -0.036348
# ALLSIL    -0.036593
# T84       -0.038673
# LS513     -0.039040
# JHH4      -0.040916
# SCC9      -0.051332
# NCIN87    -0.059982
# PK59      -0.072012
#
# [475 rows x 1 columns]

# %%
ccle = pd.read_csv(os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_ccle.csv"),index_col=0)
for ix, row in ccle.iterrows():
    dic = disease_from_name(ix,all_lines)
    ccle.loc[ix,'Name'] = dic['Name']
    ccle.at[ix,'Disease'] = dic['Disease']
    ccle.loc[ix,'CellosaurusID'] = dic['CellosaurusID']
ccle.to_excel(os.path.join(setup.discover_out_dir,"processed_cell_lines_info_ccle.xlsx"))
ccle
# Out:
#              DMB006         Name  \
# NCIH1184   0.323423    NCI-H1184
# NCIH1092   0.302924    NCI-H1092
# NCIH1155   0.255616    NCI-H1155
# NCIH1694   0.237658    NCI-H1694
# NCIH1341   0.213815    NCI-H1341
# NCIH810    0.204059     NCI-H810
# IMR32      0.197496       IMR-32
# DMS114     0.190738      DMS 114
# DU145      0.182297        DU145
# MFE280     0.157549      MFE-280
# KYSE450    0.157517     KYSE-450
# KNS62      0.155248       KNS-62
# NCIH2052   0.154903    NCI-H2052
# NCIH661    0.154395     NCI-H661
# SIMA       0.154303         SiMa
# 5637       0.152333         5637
# SKNFI      0.151620      SK-N-FI
# NCIH522    0.150442     NCI-H522
# KELLY      0.150134        Kelly
# QGP1       0.146732        QGP-1
# SKNDZ      0.141480      SK-N-DZ
# SKNSH      0.138852      SK-N-SH
# KPNSI9S    0.137589    KP-N-SI9s
# SUIT2      0.133746       SUIT-2
# NCIH1651   0.132209    NCI-H1651
# NCIH211    0.131558     NCI-H211
# NCIH2170   0.129975    NCI-H2170
# NCIH1299   0.128637    NCI-H1299
# DAOY       0.128576         Daoy
# SKNBE2     0.128135   SK-N-BE(2)
# ...             ...          ...
# SNU1      -0.021676        SNU-1
# SNGM      -0.022155        SNG-M
# RAJI      -0.023657         Raji
# EB1       -0.024109          EB1
# OCUM1     -0.024237       OCUM-1
# NCIH2009  -0.024563    NCI-H2009
# NCIH3255  -0.024718    NCI-H3255
# MDAMB435S -0.025119  MDA-MB-435S
# KU812     -0.025808        Ku812
# KG1       -0.028189          KG1
# PC14      -0.028591        PC-14
# PANC0203  -0.029725   Panc 02.03
# HEC151    -0.030035      HEC-151
# NCIH441   -0.031598     NCI-H441
# NCIH1915  -0.031804    NCI-H1915
# KP3       -0.032378         KP-3
# SKCO1     -0.032464      SK-CO-1
# PATU8902  -0.033678    PaTu 8902
# HEC265    -0.034960      HEC-265
# HT1376    -0.035690      HT-1376
# HEC6      -0.036313        HEC-6
# F36P      -0.036324        F-36P
# KYSE30    -0.036348      KYSE-30
# ALLSIL    -0.036593      ALL-SIL
# T84       -0.038673          T84
# LS513     -0.039040        LS513
# JHH4      -0.040916        JHH-4
# SCC9      -0.051332     UM-SCC-9
# NCIN87    -0.059982      NCI-N87
# PK59      -0.072012        PK-59
#
#                                                      Disease CellosaurusID
# NCIH1184                           Small cell lung carcinoma     CVCL_1458
# NCIH1092                           Small cell lung carcinoma     CVCL_1454
# NCIH1155                           Large cell lung carcinoma     CVCL_1456
# NCIH1694                           Small cell lung carcinoma     CVCL_1489
# NCIH1341                           Small cell lung carcinoma     CVCL_1463
# NCIH810                            Large cell lung carcinoma     CVCL_1590
# IMR32                                          Neuroblastoma     CVCL_0346
# DMS114                             Small cell lung carcinoma     CVCL_1174
# DU145                                     Prostate carcinoma     CVCL_0105
# MFE280                            Endometrial adenocarcinoma     CVCL_1405
# KYSE450                   Esophageal squamous cell carcinoma     CVCL_1353
# KNS62                           Squamous cell lung carcinoma     CVCL_1335
# NCIH2052                    Pleural sarcomatoid mesothelioma     CVCL_1518
# NCIH661                            Large cell lung carcinoma     CVCL_1577
# SIMA                             Adrenal gland neuroblastoma     CVCL_1695
# 5637                                       Bladder carcinoma     CVCL_0126
# SKNFI                                          Neuroblastoma     CVCL_1702
# NCIH522                                  Lung adenocarcinoma     CVCL_1567
# KELLY                                          Neuroblastoma     CVCL_2092
# QGP1                              Pancreatic somatostatinoma     CVCL_3143
# SKNDZ                                          Neuroblastoma     CVCL_1701
# SKNSH                                          Neuroblastoma     CVCL_0531
# KPNSI9S                                        Neuroblastoma     CVCL_1340
# SUIT2                       Pancreatic ductal adenocarcinoma     CVCL_3172
# NCIH1651                                 Lung adenocarcinoma     CVCL_1484
# NCIH211                            Small cell lung carcinoma     CVCL_1529
# NCIH2170                        Squamous cell lung carcinoma     CVCL_1535
# NCIH1299                           Large cell lung carcinoma     CVCL_0060
# DAOY                                         Medulloblastoma     CVCL_1167
# SKNBE2                                         Neuroblastoma     CVCL_0528
# ...                                                      ...           ...
# SNU1                                       Gastric carcinoma     CVCL_0099
# SNGM                              Endometrial adenocarcinoma     CVCL_1707
# RAJI             Epstein-Barr virus-related Burkitt lymphoma     CVCL_0511
# EB1              Epstein-Barr virus-related Burkitt lymphoma     CVCL_2027
# OCUM1                Signet ring cell gastric adenocarcinoma     CVCL_3084
# NCIH2009                                 Lung adenocarcinoma     CVCL_1514
# NCIH3255                                 Lung adenocarcinoma     CVCL_6831
# MDAMB435S                                Amelanotic melanoma     CVCL_0622
# KU812        Chronic myelogenous leukemia, BCR-ABL1 positive     CVCL_0379
# KG1                                                              CVCL_UD72
# PC14                                     Lung adenocarcinoma     CVCL_1640
# PANC0203                           Pancreatic adenocarcinoma     CVCL_1633
# HEC151                            Endometrial adenocarcinoma     CVCL_2925
# NCIH441                        Papillary lung adenocarcinoma     CVCL_1561
# NCIH1915                       Non-small cell lung carcinoma     CVCL_1505
# KP3                       Pancreatic adenosquamous carcinoma     CVCL_3005
# SKCO1                                   Colon adenocarcinoma     CVCL_0626
# PATU8902                           Pancreatic adenocarcinoma     CVCL_1845
# HEC265                            Endometrial adenocarcinoma     CVCL_2928
# HT1376                                     Bladder carcinoma     CVCL_1292
# HEC6       Endometrial endometrioid adenocarcinoma, varia...     CVCL_2931
# F36P                                Myelodysplastic syndrome     CVCL_2037
# KYSE30                    Esophageal squamous cell carcinoma     CVCL_1351
# ALLSIL              Childhood T acute lymphoblastic leukemia     CVCL_1805
# T84                                     Colon adenocarcinoma     CVCL_0555
# LS513                                   Cecum adenocarcinoma     CVCL_1386
# JHH4                                Hepatocellular carcinoma     CVCL_2787
# SCC9                          Tongue squamous cell carcinoma     CVCL_7793
# NCIN87                        Gastric tubular adenocarcinoma     CVCL_1603
# PK59                                    Pancreatic carcinoma     CVCL_4897
#
# [475 rows x 4 columns]

# %%
ctrp = pd.read_csv(os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_ctrp.csv"),index_col=0)
for ix, row in ctrp.iterrows():
    dic = disease_from_name(ix,all_lines)
    ctrp.loc[ix,'Name'] = dic['Name']
    ctrp.at[ix,'Disease'] = dic['Disease']
    ctrp.loc[ix,'CellosaurusID'] = dic['CellosaurusID']
ctrp.to_excel(os.path.join(setup.discover_out_dir,"processed_cell_lines_info_ctrp.xlsx"))
ctrp
# Out:
#              DMB006                                 Name  \
# NCIH524    0.345268                             NCI-H524
# NCIH1184   0.323423                            NCI-H1184
# DMS273     0.311811                              DMS 273
# HCC33      0.293539                                HCC33
# D283MED    0.259917                             D283 Med
# NCIH1155   0.255616                            NCI-H1155
# NCIH446    0.248096                             NCI-H446
# NCIH2029   0.233680                            NCI-H2029
# CORL95     0.222485                              COR-L95
# NCIH1341   0.213815                            NCI-H1341
# NCIH810    0.204059                             NCI-H810
# DMS53      0.200146                               DMS 53
# IMR32      0.197496                               IMR-32
# NH6        0.194401                                 NH-6
# COLO668    0.193930                             COLO 668
# DMS114     0.190738                              DMS 114
# NCIH2196   0.190196                            NCI-H2196
# DU145      0.182297                                DU145
# ECC12      0.164320                                ECC12
# CADOES1    0.163886                             CADO-ES1
# LK2        0.163578                                  LK2
# KYSE450    0.157517                             KYSE-450
# KNS62      0.155248                               KNS-62
# NCIH2052   0.154903                            NCI-H2052
# NCIH661    0.154395                             NCI-H661
# SIMA       0.154303                                 SiMa
# NCIH196    0.153562                             NCI-H196
# 5637       0.152333                                 5637
# SKNFI      0.151620                              SK-N-FI
# VCAP       0.151518                                 VCaP
# ...             ...                                  ...
# KM12      -0.023564                                 KM12
# OCUM1     -0.024237                               OCUM-1
# NCIH2009  -0.024563                            NCI-H2009
# RCM1      -0.024854  RCM-1 [Human rectum adenocarcinoma]
# MDAMB435S -0.025119                          MDA-MB-435S
# LAMA84    -0.027223                              LAMA-84
# PC14      -0.028591                                PC-14
# PANC0203  -0.029725                           Panc 02.03
# HEC151    -0.030035                              HEC-151
# NCIH441   -0.031598                             NCI-H441
# NCIH1915  -0.031804                            NCI-H1915
# KP3       -0.032378                                 KP-3
# SKCO1     -0.032464                              SK-CO-1
# PATU8902  -0.033678                            PaTu 8902
# AM38      -0.034345                                AM-38
# HEC265    -0.034960                              HEC-265
# NCIH838   -0.034973                             NCI-H838
# HT1376    -0.035690                              HT-1376
# HEC6      -0.036313                                HEC-6
# KYSE30    -0.036348                              KYSE-30
# ALLSIL    -0.036593                              ALL-SIL
# T84       -0.038673                                  T84
# LS513     -0.039040                                LS513
# SNU601    -0.039238                              SNU-601
# JHH4      -0.040916                                JHH-4
# SNU308    -0.043055                              SNU-308
# SCC9      -0.051332                             UM-SCC-9
# NCIN87    -0.059982                              NCI-N87
# PK59      -0.072012                                PK-59
# HEC108    -0.075337                              HEC-108
#
#                                                      Disease CellosaurusID
# NCIH524                            Small cell lung carcinoma     CVCL_1568
# NCIH1184                           Small cell lung carcinoma     CVCL_1458
# DMS273                             Small cell lung carcinoma     CVCL_1176
# HCC33                              Small cell lung carcinoma     CVCL_2058
# D283MED                                      Medulloblastoma     CVCL_1155
# NCIH1155                           Large cell lung carcinoma     CVCL_1456
# NCIH446                            Small cell lung carcinoma     CVCL_1562
# NCIH2029                           Small cell lung carcinoma     CVCL_1516
# CORL95                             Small cell lung carcinoma     CVCL_2418
# NCIH1341                           Small cell lung carcinoma     CVCL_1463
# NCIH810                            Large cell lung carcinoma     CVCL_1590
# DMS53                              Small cell lung carcinoma     CVCL_1177
# IMR32                                          Neuroblastoma     CVCL_0346
# NH6                              Adrenal gland neuroblastoma     CVCL_1606
# COLO668                            Small cell lung carcinoma     CVCL_1128
# DMS114                             Small cell lung carcinoma     CVCL_1174
# NCIH2196                           Small cell lung carcinoma     CVCL_1539
# DU145                                     Prostate carcinoma     CVCL_0105
# ECC12            Gastric small cell neuroendocrine carcinoma     CVCL_1189
# CADOES1                                        Ewing sarcoma     CVCL_1103
# LK2                                        Ovarian carcinoma     CVCL_W132
# KYSE450                   Esophageal squamous cell carcinoma     CVCL_1353
# KNS62                           Squamous cell lung carcinoma     CVCL_1335
# NCIH2052                    Pleural sarcomatoid mesothelioma     CVCL_1518
# NCIH661                            Large cell lung carcinoma     CVCL_1577
# SIMA                             Adrenal gland neuroblastoma     CVCL_1695
# NCIH196                            Small cell lung carcinoma     CVCL_1509
# 5637                                       Bladder carcinoma     CVCL_0126
# SKNFI                                          Neuroblastoma     CVCL_1702
# VCAP                                      Prostate carcinoma     CVCL_2235
# ...                                                      ...           ...
# KM12                                         Colon carcinoma     CVCL_1331
# OCUM1                Signet ring cell gastric adenocarcinoma     CVCL_3084
# NCIH2009                                 Lung adenocarcinoma     CVCL_1514
# RCM1                                   Rectal adenocarcinoma     CVCL_1648
# MDAMB435S                                Amelanotic melanoma     CVCL_0622
# LAMA84       Chronic myelogenous leukemia, BCR-ABL1 positive     CVCL_0388
# PC14                                     Lung adenocarcinoma     CVCL_1640
# PANC0203                           Pancreatic adenocarcinoma     CVCL_1633
# HEC151                            Endometrial adenocarcinoma     CVCL_2925
# NCIH441                        Papillary lung adenocarcinoma     CVCL_1561
# NCIH1915                       Non-small cell lung carcinoma     CVCL_1505
# KP3                       Pancreatic adenosquamous carcinoma     CVCL_3005
# SKCO1                                   Colon adenocarcinoma     CVCL_0626
# PATU8902                           Pancreatic adenocarcinoma     CVCL_1845
# AM38                                            Glioblastoma     CVCL_1070
# HEC265                            Endometrial adenocarcinoma     CVCL_2928
# NCIH838                                  Lung adenocarcinoma     CVCL_1594
# HT1376                                     Bladder carcinoma     CVCL_1292
# HEC6       Endometrial endometrioid adenocarcinoma, varia...     CVCL_2931
# KYSE30                    Esophageal squamous cell carcinoma     CVCL_1351
# ALLSIL              Childhood T acute lymphoblastic leukemia     CVCL_1805
# T84                                     Colon adenocarcinoma     CVCL_0555
# LS513                                   Cecum adenocarcinoma     CVCL_1386
# SNU601               Signet ring cell gastric adenocarcinoma     CVCL_0101
# JHH4                                Hepatocellular carcinoma     CVCL_2787
# SNU308                                 Gallbladder carcinoma     CVCL_5048
# SCC9                          Tongue squamous cell carcinoma     CVCL_7793
# NCIN87                        Gastric tubular adenocarcinoma     CVCL_1603
# PK59                                    Pancreatic carcinoma     CVCL_4897
# HEC108                            Endometrial adenocarcinoma     CVCL_2923
#
# [633 rows x 4 columns]

# %%
# cosids = pd.read_csv(os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_COSMIC_IDS_gdsc.csv"),index_col=0)

# %%
# all_lines['Disease']
# Out:
# Empty DataFrame
# Columns: [CellosaurusID, CosmicIDs, Databases, Disease, Names]
# Index: []

# %%
# ?all_lines.loc['CVCL_1454']
# Out:
# CellosaurusID                                          [CVCL_1454]
# CosmicIDs        [687997, 850434, 877104, 877371, 980941, 10218...
# Databases        [CLO, EFO, ArrayExpress, ArrayExpress, ArrayEx...
# Disease                                  Small cell lung carcinoma
# Names                                   [NCI-H1092, H1092, H-1092]
# Name: CVCL_1454, dtype: object

# %%
ccle

# %%
os.path.join(setup.discover_out_dir,"cell_lines_IDs_and_types_ccle.csv")
pickle.dump(ccle, file=open('data/raw/cellosaurus/cellosaurus_cosmic_cell_lines.p','wb'))

# %%
# "DMB006": "DMB006",
run_pipeline("DMB006")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/DMB006.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, DMB006 to DMB006
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/DMB006/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called DMB006_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" DMB006

# %%
# "ICB984": "ICB984",
run_pipeline("ICB984")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/ICB984.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, ICB984 to ICB984
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/ICB984/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called ICB984_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" ICB984

# %%
# "ICB1299": "ICB1299",
run_pipeline("ICB1299")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/ICB1299.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, ICB1299 to ICB1299
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/ICB1299/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called ICB1299_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" ICB1299

# %%
cosmic_lines
# Out:
#           CellosaurusID                                          CosmicIDs  \
# CVCL_D231   [CVCL_D231]                          [889083, 946049, 1066155]
# CVCL_7942   [CVCL_7942]                                   [876687, 905206]
# CVCL_4806   [CVCL_4806]                                           [721372]
# CVCL_8029   [CVCL_8029]                                           [876702]
# CVCL_VJ83   [CVCL_VJ83]                                          [2543722]
# CVCL_D856   [CVCL_D856]                                          [1731373]
# CVCL_D857   [CVCL_D857]                                          [1731374]
# CVCL_D776   [CVCL_D776]                                          [1731375]
# CVCL_D777   [CVCL_D777]                                          [1731376]
# CVCL_S745   [CVCL_S745]                                          [1890459]
# CVCL_8030   [CVCL_8030]                                   [905207, 972280]
# CVCL_8031   [CVCL_8031]                                           [876688]
# CVCL_8033   [CVCL_8033]                                           [876689]
# CVCL_8034   [CVCL_8034]                                           [876690]
# CVCL_VJ84   [CVCL_VJ84]                                          [2543723]
# CVCL_5239   [CVCL_5239]  [686410, 905861, 972275, 1155274, 1155554, 118...
# CVCL_N588   [CVCL_N588]                                          [2307723]
# CVCL_8036   [CVCL_8036]                                           [876691]
# CVCL_7943   [CVCL_7943]                          [876682, 877280, 1042622]
# CVCL_0Q73   [CVCL_0Q73]                                          [1432838]
# CVCL_8039   [CVCL_8039]                                           [876703]
# CVCL_2265   [CVCL_2265]                                          [2402466]
# CVCL_8040   [CVCL_8040]                                           [876692]
# CVCL_Z019   [CVCL_Z019]                                           [876693]
# CVCL_Z020   [CVCL_Z020]                                           [876694]
# CVCL_8041   [CVCL_8041]                                          [2163791]
# CVCL_W281   [CVCL_W281]                                          [1418452]
# CVCL_S560   [CVCL_S560]                                           [905208]
# CVCL_8042   [CVCL_8042]                                           [876704]
# CVCL_8043   [CVCL_8043]                                           [876695]
# ...                 ...                                                ...
# CVCL_J069   [CVCL_J069]                                 [1548869, 2439355]
# CVCL_EI23   [CVCL_EI23]                                          [2439356]
# CVCL_B485   [CVCL_B485]                        [1197391, 1548870, 2013572]
# CVCL_B486   [CVCL_B486]                                 [1548871, 2439361]
# CVCL_J070   [CVCL_J070]                                 [1548872, 2439364]
# CVCL_A746   [CVCL_A746]                                          [1197388]
# CVCL_J526   [CVCL_J526]                                          [1548873]
# CVCL_B487   [CVCL_B487]                                          [1548874]
# CVCL_EI16   [CVCL_EI16]                                          [2439372]
# CVCL_A747   [CVCL_A747]                        [1197389, 1921229, 2439373]
# CVCL_R736   [CVCL_R736]                                          [1921231]
# CVCL_R737   [CVCL_R737]                                          [1921232]
# CVCL_R738   [CVCL_R738]                                          [1921230]
# CVCL_G332   [CVCL_G332]                                 [1548875, 2439374]
# CVCL_J527   [CVCL_J527]                                          [1548876]
# CVCL_J528   [CVCL_J528]                                          [1548881]
# CVCL_J071   [CVCL_J071]                                 [1548877, 2439381]
# CVCL_G333   [CVCL_G333]                                          [1548882]
# CVCL_J530   [CVCL_J530]                                          [1548883]
# CVCL_J531   [CVCL_J531]                                          [1548878]
# CVCL_EI18   [CVCL_EI18]                                          [2439392]
# CVCL_J072   [CVCL_J072]                                          [1548884]
# CVCL_IU88   [CVCL_IU88]                                          [2491094]
# CVCL_B077   [CVCL_B077]                        [2078183, 2088021, 2296992]
# CVCL_IU89   [CVCL_IU89]                                          [2491095]
# CVCL_D596   [CVCL_D596]                         [930337, 1046039, 1123029]
# CVCL_9920   [CVCL_9920]                                          [1529906]
# CVCL_0588   [CVCL_0588]  [687503, 755295, 871152, 877452, 894094, 90439...
# CVCL_1661   [CVCL_1661]  [687504, 871160, 877444, 894095, 904399, 90990...
# CVCL_5614   [CVCL_5614]                                 [1136345, 1176641]
#
#                                                    Databases  \
# CVCL_D231  [ChEMBL-Cells, ChEMBL-Targets, Cosmic, Cosmic,...
# CVCL_7942                 [CGH-DB, Cosmic, Cosmic, Wikidata]
# CVCL_4806                                 [Cosmic, Wikidata]
# CVCL_8029                                 [Cosmic, Wikidata]
# CVCL_VJ83                                           [Cosmic]
# CVCL_D856                                 [Cosmic, Wikidata]
# CVCL_D857                                 [Cosmic, Wikidata]
# CVCL_D776                                 [Cosmic, Wikidata]
# CVCL_D777                                 [Cosmic, Wikidata]
# CVCL_S745                                 [Cosmic, Wikidata]
# CVCL_8030       [BTO, CGH-DB, Cosmic, Cosmic, GEO, Wikidata]
# CVCL_8031                                 [Cosmic, Wikidata]
# CVCL_8033                            [Cosmic, GEO, Wikidata]
# CVCL_8034                                 [Cosmic, Wikidata]
# CVCL_VJ84                                           [Cosmic]
# CVCL_5239  [BTO, CLO, EFO, ATCC, BioSample, Coriell, Cosm...
# CVCL_N588                                 [Cosmic, Wikidata]
# CVCL_8036                                 [Cosmic, Wikidata]
# CVCL_7943  [Cosmic, Cosmic, Cosmic, GEO, GEO, GEO, Wikidata]
# CVCL_0Q73                            [BTO, Cosmic, Wikidata]
# CVCL_8039                                 [Cosmic, Wikidata]
# CVCL_2265  [CLO, CLDB, CCRID, Cosmic, ECACC, ICLC, NCBI_I...
# CVCL_8040                                 [Cosmic, Wikidata]
# CVCL_Z019                                 [Cosmic, Wikidata]
# CVCL_Z020                                 [Cosmic, Wikidata]
# CVCL_8041                         [Cosmic, ESTDAB, Wikidata]
# CVCL_W281                                 [Cosmic, Wikidata]
# CVCL_S560                         [CGH-DB, Cosmic, Wikidata]
# CVCL_8042                                 [Cosmic, Wikidata]
# CVCL_8043                                 [Cosmic, Wikidata]
# ...                                                      ...
# CVCL_J069                         [Cosmic, Cosmic, Wikidata]
# CVCL_EI23                                 [Cosmic, Wikidata]
# CVCL_B485                 [Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_B486                         [Cosmic, Cosmic, Wikidata]
# CVCL_J070                         [Cosmic, Cosmic, Wikidata]
# CVCL_A746                                 [Cosmic, Wikidata]
# CVCL_J526                                 [Cosmic, Wikidata]
# CVCL_B487                                 [Cosmic, Wikidata]
# CVCL_EI16                                 [Cosmic, Wikidata]
# CVCL_A747                 [Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_R736                                 [Cosmic, Wikidata]
# CVCL_R737                                 [Cosmic, Wikidata]
# CVCL_R738                                 [Cosmic, Wikidata]
# CVCL_G332                         [Cosmic, Cosmic, Wikidata]
# CVCL_J527                                 [Cosmic, Wikidata]
# CVCL_J528                                 [Cosmic, Wikidata]
# CVCL_J071                         [Cosmic, Cosmic, Wikidata]
# CVCL_G333                                 [Cosmic, Wikidata]
# CVCL_J530                                 [Cosmic, Wikidata]
# CVCL_J531                                 [Cosmic, Wikidata]
# CVCL_EI18                                 [Cosmic, Wikidata]
# CVCL_J072                                 [Cosmic, Wikidata]
# CVCL_IU88                                 [Cosmic, Wikidata]
# CVCL_B077  [EFO, ATCC, BioSample, Cosmic, Cosmic, Cosmic,...
# CVCL_IU89                                 [Cosmic, Wikidata]
# CVCL_D596         [CGH-DB, Cosmic, Cosmic, Cosmic, Wikidata]
# CVCL_9920                            [Cosmic, GEO, Wikidata]
# CVCL_0588  [BTO, CLO, EFO, MCCL, CLDB, CLDB, CLDB, CLDB, ...
# CVCL_1661  [BTO, CLO, EFO, CLDB, CLDB, CLDB, ArrayExpress...
# CVCL_5614  [EFO, Cosmic, Cosmic, GEO, GEO, GEO, GEO, LINC...
#
#                                                      Disease  \
# CVCL_D231                                Lung adenocarcinoma
# CVCL_7942                                           Melanoma
# CVCL_4806                                 Prostate carcinoma
# CVCL_8029                                           Melanoma
# CVCL_VJ83                                 Cutaneous melanoma
# CVCL_D856                                Lung adenocarcinoma
# CVCL_D857                                Lung adenocarcinoma
# CVCL_D776                                Lung adenocarcinoma
# CVCL_D777                                Lung adenocarcinoma
# CVCL_S745                                Lung adenocarcinoma
# CVCL_8030                                           Melanoma
# CVCL_8031                                           Melanoma
# CVCL_8033                                           Melanoma
# CVCL_8034                                           Melanoma
# CVCL_VJ84                                 Cutaneous melanoma
# CVCL_5239                                           Melanoma
# CVCL_N588                                   Synovial sarcoma
# CVCL_8036                                           Melanoma
# CVCL_7943                                           Melanoma
# CVCL_0Q73                                      Endometriosis
# CVCL_8039                                           Melanoma
# CVCL_2265           Childhood T acute lymphoblastic leukemia
# CVCL_8040                                           Melanoma
# CVCL_Z019                                           Melanoma
# CVCL_Z020                                           Melanoma
# CVCL_8041                                           Melanoma
# CVCL_W281                                           Melanoma
# CVCL_S560                                           Melanoma
# CVCL_8042                                           Melanoma
# CVCL_8043                                           Melanoma
# ...                                                      ...
# CVCL_J069                                 Cutaneous melanoma
# CVCL_EI23                                 Cutaneous melanoma
# CVCL_B485                                 Cutaneous melanoma
# CVCL_B486                                 Cutaneous melanoma
# CVCL_J070                                 Cutaneous melanoma
# CVCL_A746                                           Melanoma
# CVCL_J526                                   Mucosal melanoma
# CVCL_B487                                 Cutaneous melanoma
# CVCL_EI16                                 Cutaneous melanoma
# CVCL_A747                                           Melanoma
# CVCL_R736                                           Melanoma
# CVCL_R737                                           Melanoma
# CVCL_R738                                           Melanoma
# CVCL_G332                                 Cutaneous melanoma
# CVCL_J527                                 Cutaneous melanoma
# CVCL_J528                                           Melanoma
# CVCL_J071                                 Cutaneous melanoma
# CVCL_G333                         Acral lentiginous melanoma
# CVCL_J530                         Acral lentiginous melanoma
# CVCL_J531                                           Melanoma
# CVCL_EI18                                 Cutaneous melanoma
# CVCL_J072                         Acral lentiginous melanoma
# CVCL_IU88  B acute lymphoblastic leukemia with t(9;22)(q3...
# CVCL_B077                               Mantle cell lymphoma
# CVCL_IU89  B acute lymphoblastic leukemia with t(9;22)(q3...
# CVCL_D596                Oral cavity squamous cell carcinoma
# CVCL_9920                                       Osteosarcoma
# CVCL_0588  Invasive ductal carcinoma, not otherwise speci...
# CVCL_1661  Invasive ductal carcinoma, not otherwise speci...
# CVCL_5614  Invasive ductal carcinoma, not otherwise speci...
#
#                                                        Names
# CVCL_D231                                             [1-87]
# CVCL_7942  [1011-mel, 1011-MEL, 1011 mel, 1011mel, 1011, ...
# CVCL_4806                                    [1013L, 1013-L]
# CVCL_8029     [1088-mel, 1088-MEL, 1088 Mel, 1088 mel, 1088]
# CVCL_VJ83                                      [10CM, 10 CM]
# CVCL_D856                         [11-18-ER1-7, 11-18/ER1-7]
# CVCL_D857                         [11-18-ER2-1, 11-18/ER2-1]
# CVCL_D776                     [11-18-GEF10-1, 11-18/GEF10-1]
# CVCL_D777                     [11-18-GEF20-1, 11-18/GEF20-1]
# CVCL_S745                        [11-18/R, 11-18R, 11-18/ER]
# CVCL_8030  [1102-mel, 1102-MEL, 1102 mel, 1102mel, 1102, ...
# CVCL_8031               [1143-mel, 1143-MEL, 1143 mel, 1143]
# CVCL_8033               [1195-mel, 1195-MEL, 1195 mel, 1195]
# CVCL_8034               [1199-mel, 1199-MEL, 1199 mel, 1199]
# CVCL_VJ84                                      [11CM, 11 CM]
# CVCL_5239  [1205Lu, 1205-Lu, 1205 Lu, WM 1205LU, WM-1205L...
# CVCL_N588                                    [1273/99, 1273]
# CVCL_8036               [1280-mel, 1280-MEL, 1280 mel, 1280]
# CVCL_7943  [1290-mel, 1290-MEL, 1290 mel, 1290, MG-1290, ...
# CVCL_0Q73                        [12Z, 12z, 12-Z, Z12, Z-12]
# CVCL_8039               [1300-mel, 1300-MEL, 1300 mel, 1300]
# CVCL_2265                                             [1301]
# CVCL_8040               [1317-mel, 1317-MEL, 1317 mel, 1317]
# CVCL_Z019                               [1335-mel, 1335-MEL]
# CVCL_Z020                               [1352-mel, 1352-MEL]
# CVCL_8041     [1359-mel, 1359-MEL, 1359 mel, 1359, Mel-1359]
# CVCL_W281                                            [136-2]
# CVCL_S560            [1362-mel, 1362-MEL, 1362 mel, 1362mel]
# CVCL_8042               [1363-mel, 1363-MEL, 1363 mel, 1363]
# CVCL_8043               [1376-mel, 1376-MEL, 1376 mel, 1376]
# ...                                                      ...
# CVCL_J069                                            [YUPLA]
# CVCL_EI23                                            [YUPOM]
# CVCL_B485                                            [YURIF]
# CVCL_B486                                            [YUROB]
# CVCL_J070                                            [YUROL]
# CVCL_A746                  [YUSAC2, YUSAC-2, YUSAC 2, YUSAC]
# CVCL_J526                                            [YUSAN]
# CVCL_B487                                            [YUSIK]
# CVCL_EI16                                           [YUSIPU]
# CVCL_A747  [YUSIT1, YUSIT-1, YUSIT 1, Yusit-1, YUSITI, Yu...
# CVCL_R736                                       [YUSIT1-B11]
# CVCL_R737                                       [YUSIT1-B31]
# CVCL_R738                                        [YUSIT1-B5]
# CVCL_G332                                            [YUSIV]
# CVCL_J527                                            [YUSTE]
# CVCL_J528                                            [YUTHO]
# CVCL_J071                                           [YUTICA]
# CVCL_G333                                    [YUVON3, YUVON]
# CVCL_J530                                           [YUWERA]
# CVCL_J531                                            [YUWIM]
# CVCL_EI18                                            [YUZAZ]
# CVCL_J072                                            [YUZOR]
# CVCL_IU88                                      [Z-119, Z119]
# CVCL_B077                                      [Z-138, Z138]
# CVCL_IU89                                      [Z-181, Z181]
# CVCL_D596                                               [ZA]
# CVCL_9920                                      [ZK-58, ZK58]
# CVCL_0588                   [ZR-75-1, ZR751, ZR75-1, ZR75_1]
# CVCL_1661                        [ZR-75-30, ZR7530, ZR75-30]
# CVCL_5614           [ZR-75-B, ZR75-B, ZR-75B, ZR-75b, ZR75B]
#
# [4752 rows x 5 columns]

# %%
# "ICB1487": "ICB1487",
run_pipeline("ICB1487")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/ICB1487.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, ICB1487 to ICB1487
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/ICB1487/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called ICB1487_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" ICB1487

# %%
# "ICB1572": "ICB1572",
run_pipeline("ICB1572")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/ICB1572.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, ICB1572 to ICB1572
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/ICB1572/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called ICB1572_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" ICB1572

# %%
# "MB002": "MB002",
run_pipeline("MB002")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MB002.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MB002 to MB002
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MB002/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MB002_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MB002

# %%
# "MB009": "MB009",
run_pipeline("MB009")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MB009.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MB009 to MB009
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MB009/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MB009_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MB009

# %%
# "MED211": "MED211",
run_pipeline("MED211")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MED211.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MED211 to MED211
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MED211/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MED211_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MED211

# %%
# "MED411": "MED411",
run_pipeline("MED411")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MED411.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MED411 to MED411
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MED411/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MED411_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MED411

# %%
# "MED1712": "MED1712",
run_pipeline("MED1712")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MED1712.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MED1712 to MED1712
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MED1712/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MED1712_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MED1712

# %%
# "MED1911": "MED1911",
run_pipeline("MED1911")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MED1911.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MED1911 to MED1911
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MED1911/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MED1911_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MED1911

# %%
# "MED2312": "MED2312",
run_pipeline("MED2312")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/MED2312.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, MED2312 to MED2312
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/MED2312/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called MED2312_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" MED2312

# %%
# "RCMB18": "RCMB18",
run_pipeline("RCMB18")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB18.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB18 to RCMB18
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB18/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB18_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB18

# %%
# "RCMB20": "RCMB20",
run_pipeline("RCMB20")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB20.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB20 to RCMB20
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB20/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB20_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB20

# %%
# "RCMB24": "RCMB24",
run_pipeline("RCMB24")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB24.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB24 to RCMB24
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB24/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB24_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB24

# %%
# "RCMB28": "RCMB28",
run_pipeline("RCMB28")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB28.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB28 to RCMB28
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB28/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB28_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB28

# %%
# "RCMB32": "RCMB32",
run_pipeline("RCMB32")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB32.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB32 to RCMB32
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB32/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB32_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB32

# %%
# "RCMB38": "RCMB38",
run_pipeline("RCMB38")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB38.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB38 to RCMB38
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB38/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB38_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB38

# %%
# "RCMB40": "RCMB40"
run_pipeline("RCMB40")
# Out:
# ======================================
# Step 1: read_user_input
# ======================================
# Reminder: if you want to use a custom control expresion, you must set control to 'custom'
# ==> Setting patient_dir = case_id
# Setup done!
# ======================================
# Step 2: download_and_preprocess_rnaseq
# ======================================
# ==> Checking if local file (/pdx-hts/Notebooks/data/preprocessed/exp/RCMB40.csv) exist.
# ==> This file containes the expression of the PDXs. Printing dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, RCMB40 to RCMB40
# Columns: 16247 entries, A1BG to ZZZ3
# dtypes: float64(16247)
# memory usage: 126.9+ KB
# ==> None
# ==> File /pdx-hts/Notebooks/patients/RCMB40/gene_abundance.sleuth.csv saved successfully
# ==> Done preprocessing!
# ======================================
# Step 3: classify_sample
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 4: run_discover
# ======================================
# These are not the analyses you are looking for. Move along!
# ======================================
# Step 5: run_cmap
# ======================================
# ==> About to parse CMap results.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /opt/conda/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ==> done!
# ==> Merging results from DiSCoVER and CMap.
# done!
# ==> Done Merging results from DiSCoVER and CMap!
# ==> Saving combined_df and to_slide on setup variable
# ==> Saving the combined DiSCoVER+CMap resuls to a csv called RCMB40_combined_DISCoVER_and_CMap_results.csv
# ==> Done done!
# All analyses completed suscessfully with "patient" RCMB40

# %%
print('done!')
# Out:
# done!

# %%
# Requires GenePattern Notebook: pip install genepattern-notebook
import gp
import genepattern

# Username and password removed for security reasons.
genepattern.display(genepattern.session.register("https://cloud.genepattern.org/gp", "", ""))
# Out:
# GPAuthWidget()

# %%
@genepattern.build_ui(parameters={
    "output_var": {
        "default": "case_id",
        "hide": False,
    },
    "case_id": {"type": "choice",
                "description": "The name of the case, e.g., 'BT084'",
                "choices": {
                    "BT084": "BT084",
                    "DMB006": "DMB006",
                    "ICB984": "ICB984",
                    "ICB1299": "ICB1299",
                    "ICB1487": "ICB1487",
                    "ICB1572": "ICB1572",
                    "MB002": "MB002",
                    "MB009": "MB009",
                    "MED211": "MED211",
                    "MED411": "MED411",
                    "MED1712": "MED1712",
                    "MED1911": "MED1911",
                    "MED2312": "MED2312",
                    "RCMB18": "RCMB18",
                    "RCMB20": "RCMB20",
                    "RCMB24": "RCMB24",
                    "RCMB28": "RCMB28",
                    "RCMB32": "RCMB32",
                    "RCMB38": "RCMB38",
                    "RCMB40": "RCMB40",},
               "default":"BT084"},
})
def set_case_id(case_id):
    print(f'case_id set to "{case_id}"')
    return case_id
# Out:
# UIBuilder(function_import='set_case_id', name='set_case_id', params=[{'name': 'case_id', 'label': 'case_id', '…

# %% [markdown]
# ## User input

# %% [markdown]
# Select parameters before running the rest of the notebook.

# %% [markdown]
# <div class="alert alert-info">
# <h3 style="margin-top: 0;"> Instructions <i class="fa fa-info-circle"></i></h3>
# Select parameters before running the rest of the notebook.
# </div>

# %%
from companion_script import *
# # Select case
# case_id = 'case17'
# # This patient directory should match the directory name on DNANexus.
# patient_dir = '18-10716_tumor-normal'
# is_medullo = True # set False if it is another kind of brain tumor
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import readline # required for rpy2 extension
# %load_ext rpy2.ipython


def rmagic_warning(
    message,
    category = rpy2.rinterface.RRuntimeWarning,
    filename = '',
    lineno = -1,
    file=None,
    line=None):
    print(message)
default_showwarning = warnings.showwarning


@genepattern.build_ui(parameters={
    "output_var": {
        "default": "setup",
        "hide": False,
    },
    "case_id": {"type": "text",
                "description": "The name of the case, e.g., 'PDX1'",
               "default":"PDX1"},
    "patient_dir": {"type": "text",
                    "description": 'For DNA Nexus downloads only. The name of the "patient" directory, e.g. "18-10716_tumor-normal" (quotes are required)',
                    "default":"PDX1_dir"},
    "dna_nexus_bool": {"type": "bool",
                   "description": "Whether or not this sample has been classified as medulloblastoma",
                  "default":False},
    "is_medullo": {"type": "bool",
                   "description": "Whether or not this sample has been classified as medulloblastoma",},
    "control": {"type": "choice",
                "description": "Whether or not to use a custom control",
                "choices": {
                    "original": "original",
                    "custom": "custom",
                            }
               },
    "custom_control_expression": {"type": "file",
                           "kinds": ["gct"],
                           "description": "The file (or path to the GCT file) which contains the gene expression of the custom control.",
                           "default":None},
})
def read_user_input(case_id, patient_dir, dna_nexus_bool=False, is_medullo=False, control='original',custom_control_expression=None):
    # Select control for DiSCoVER and Connectivity Map
    # Generally, if the tumor is a medulloblastoma, we use `cerebellar_stem` (comment the `neural_stem` line).
    # And if it is any other kind of brain tumor, we use `neural_stem`.
    if control == 'original':
        expression_control = 'cerebellar_stem' if is_medullo else 'neural_stem'
    elif control == 'custom':
        expression_control = 'custom_control'
    else:
        print('Unexpected value for variable named control, value:', control)
        
    if (len(custom_control_expression) is not 0) and (control is not 'custom'):
        print("Reminder: if you want to use a custom control expresion, you must set control to 'custom'")

    base_dir = os.getcwd()
    utilities_dir = '/build'
    patients_dir = os.path.join(base_dir, 'patients')
    if not dna_nexus_bool:
        log('Setting patient_dir = case_id')
        patient_dir = case_id
        
    in_dir = os.path.join(patients_dir, patient_dir)
    
    out_dir = in_dir
    os.makedirs(out_dir, exist_ok=True)
    
#     out['base_dir'] = base_dir
#     out['utilities_dir'] = utilities_dir
#     out['patients_dir'] = patients_dir
#     

    platform = sys.platform
    if platform.startswith('linux'):
        os_string = 'linux'
    elif platform == 'darwin':
        os_string = 'mac'
    else:
        raise ValueError('Platform "{}" not supported'.format(platform))

    # RNASeq quantification
    kallisto_dir = '/build/kallisto'
    kallisto_path = os.path.join(kallisto_dir, 'kallisto_{}-v0.44.0/kallisto'.format(os_string))
    transcriptome_index_path = os.path.join(kallisto_dir, 'GRCh38.ensembl.transcriptome.idx')
    local_fastqs_dir = os.path.join(in_dir, 'fastqs')
    os.makedirs(local_fastqs_dir, exist_ok=True)
    patient_gexp_file = os.path.join(out_dir, 'gene_abundance.sleuth.csv')

    # Medulloblastoma classification
#     from sklearn.ensemble import RandomForestClassifier
#     from tumor_classification.medulloblastoma import classify_cavalli, classify_cho, classify_northcott
    medullo_classify_out_dir = os.path.join(out_dir, 'medulloblastoma_classification')
    if not os.path.exists(medullo_classify_out_dir):
        os.mkdir(medullo_classify_out_dir)
    cavalli_subgroup_file = os.path.join(medullo_classify_out_dir, 'cavalli_subgroups.csv')
    cavalli_subgroup_direct_file = os.path.join(medullo_classify_out_dir, 'cavalli_subgroups_direct.csv')
    cavalli_subtype_file = os.path.join(medullo_classify_out_dir, 'cavalli_subtypes.csv')
    cho_subtype_file = os.path.join(medullo_classify_out_dir, 'cho_subtypes.csv')
    cho_subgroup_file = os.path.join(medullo_classify_out_dir, 'cho_subgroups.csv')
    northcott_subgroup_file = os.path.join(medullo_classify_out_dir, 'northcott_subgroups.csv')

    drug_suggestion_out_dir = os.path.join(out_dir, 'drug_suggestions')
    os.makedirs(drug_suggestion_out_dir, exist_ok=True)

    # DiSCoVER
    discover_out_dir = os.path.join(drug_suggestion_out_dir, 'discover/{}'.format(expression_control))
    os.makedirs(discover_out_dir, exist_ok=True)
    discover_heatmap_file = os.path.join(discover_out_dir, 'ctrp.png')
    full_discover_results_file = os.path.join(discover_out_dir, 'discover.all.csv')
    rdrugs_discover_file = os.path.join(discover_out_dir, '{}.discover.{}.reasonable.annotated.csv'.format(case_id, expression_control))

    # Connectivity Map
    cmap_out_dir = os.path.join(drug_suggestion_out_dir, 'cmap/{}'.format(expression_control))
    os.makedirs(cmap_out_dir, exist_ok=True)
    cmap_all_ranked_drugs_file = os.path.join(cmap_out_dir, '{}.cmap.{}.all.csv'.format(case_id, expression_control))
    cmap_reasonable_ranked_drugs_file = os.path.join(cmap_out_dir, '{}.cmap.{}.reasonable.annotated.csv'.format(case_id, expression_control))
    
    # Powerpoint for MTB
#     from slides import make_medullo_classification_slide, make_discover_workflow_slide, make_exp_drug_ranking_results_slide, make_intersection_slide
    mtb_ppt_file = os.path.join(out_dir, '{}.mtb_slides.pptx'.format(case_id))

    # DNANexus
    dx_source_path = os.path.join(utilities_dir, 'dx-toolkit/environment')
    dnanexus_project = 'UW_UCSD_RNAseq_collaboration_share'
    # Replace the contents of this file with your own DNANexus token.
    dnanexus_token_file = os.path.join(base_dir, 'dnanexus_token.txt')
    # To use the dx command, we must update some environment variables. 
    # From the command line, this is done with source dx-toolkit/environment, 
    # but from Python we have to use a workaround, because normally any changes 
    # to environment variables done in a subprocess are not reflected in the 
    # parent process. The workaround runs the source command in a subprocess, 
    # fetches the environment variables from the subprocess and updates those 
    # of the parent process.
#     from utils import source_and_update_env_vars
    source_and_update_env_vars(dx_source_path)    
    out = {"case_id": case_id,
                 "patient_dir": patient_dir,
                 "is_medullo": is_medullo}
    out['dna_nexus_bool']=dna_nexus_bool
    out['expression_control'] = expression_control
    out['custom_control_expression'] = custom_control_expression
    out['dnanexus_token_file'] = dnanexus_token_file
    out['local_fastqs_dir'] = local_fastqs_dir
    out['dnanexus_project'] = dnanexus_project
    out['local_fastqs_dir'] = local_fastqs_dir
    out['transcriptome_index_path'] = transcriptome_index_path
    out['kallisto_path'] = kallisto_path
    out['kallisto_dir'] = kallisto_dir
    out['out_dir'] = out_dir
    out['r_out_dir'] = out_dir.replace('\\',r'\\')
    out['patient_gexp_file'] = patient_gexp_file
    out['in_dir'] = in_dir
    out['cavalli_subgroup_file'] = cavalli_subgroup_file
    out['cavalli_subtype_file'] = cavalli_subtype_file
    out['cavalli_subgroup_direct_file'] = cavalli_subgroup_direct_file
    out['cho_subgroup_file'] = cho_subgroup_file
    out['cho_subtype_file'] = cho_subtype_file
    out['northcott_subgroup_file'] = northcott_subgroup_file
    out['mtb_ppt_file'] = mtb_ppt_file
    out['expression_control'] = expression_control
    out['full_discover_results_file'] = full_discover_results_file
    out['discover_out_dir'] = discover_out_dir
    out['discover_heatmap_file'] = discover_heatmap_file
    out['rdrugs_discover_file'] = rdrugs_discover_file
    out['cmap_out_dir'] = cmap_out_dir
    out['cmap_all_ranked_drugs_file'] = cmap_all_ranked_drugs_file
    out['cmap_reasonable_ranked_drugs_file'] = cmap_reasonable_ranked_drugs_file
    out['mtb_ppt_file'] = mtb_ppt_file
    out['out_dir'] = os.path.join(patients_dir, case_id)

    if not os.path.exists(out['out_dir']):
        os.mkdir(out['out_dir'])
    print('Setup done!')
    pickle.dump(out, file=open(os.path.join(out['out_dir'], case_id+'_backup1_input.p'),'wb'))
    return Bunch(out)
# Out:
# UIBuilder(function_import='read_user_input', name='read_user_input', params=[{'name': 'case_id', 'label': 'cas…

# %% [markdown]
# <div class="well">
# Running all cells below this point will execute all the analyses except for one: the Connectivity Map analysis at the end of the notebook, which requires two manual steps.
# </div>

# %% [markdown]
# # Download RNAseq data

# %%
@genepattern.build_ui(parameters={
    "setup": {"default": "setup",
              "hide": False,
              "description": "The variable which has the setup information"},
    "input_expression_dir":{"hide":True},
    "output_var": {
        "default": "setup",
        "hide": True,
    },
})
def download_and_preprocess_rnaseq(setup, input_expression_dir = None):
    setup.input_expression_dir = f'/pdx-hts/Notebooks/data/preprocessed/exp/{setup.case_id}.csv'
    if setup.dna_nexus_bool:
        if input_expression_dir is not None:
            log(f"input_expression_dir has a value ({setup.input_expression_dir}), and it will be ignored!")
        log('About to download fastqfiles from DNA Nexus. This may take a while.')
        with open(setup.dnanexus_token_file, 'r') as f:
            dnanexus_token = f.readline().strip()
        login_command = 'dx login --token {} --noprojects; dx select {}'.format(dnanexus_token, setup.dnanexus_project)
        # subprocess.check_output('ls', shell=True).decode('utf-8').strip()
        subprocess.check_output(login_command, shell=True).decode('utf-8').strip()

        find_fastq_command = 'dx find data --name "*.fastq.gz" --path {}:{}'.format(setup.dnanexus_project, setup.patient_dir)
        find_fastq_return_lines = subprocess.check_output(find_fastq_command, shell=True).decode().strip().split('\n')
        re_string = '.*(/{}/.*\.fastq.gz) .*'.format(setup.patient_dir)
        fastq_path_re = re.compile(re_string)
        remote_fastq_paths = []
        local_fastq_subdirs = []

        for line in find_fastq_return_lines:
            search = fastq_path_re.search(line)
            remote_fastq_path = search.group(1)
            remote_fastq_paths.append(remote_fastq_path)
            fastq_subdir_path = os.path.dirname(remote_fastq_path)
            fastq_subdir = os.path.basename(fastq_subdir_path)
            local_fastq_subdir = os.path.join(setup.local_fastqs_dir, fastq_subdir)
            os.makedirs(local_fastq_subdir, exist_ok=True)
            local_fastq_subdirs.append(local_fastq_subdir)

        for remote_fastq_path, local_fastq_subdir in zip(remote_fastq_paths, local_fastq_subdirs):
            download_command = 'dx download "{}" -o "{}"'.format(remote_fastq_path, local_fastq_subdir)
            print('\t'+download_command)
            try:
                a=subprocess.check_output(download_command, shell=True)
            except subprocess.CalledProcessError as e:
                print('\tEncountered a dx error, this likely means you already have the file indicated above.')
                print('\tContinuing...\n')
                continue
        log('Done downloading the fastq files.')
        log('Preprocessing RNASeq data now:')
        log('Using kallisto to compute transcript abundance.')
        preprocess_rna_seq(setup)
        log('Done with tanscript abundance.')
        log('Using sleuth to aggregate transcript abundance into gene abbundance.')
        run_sleuth(setup)
        patient_exp = pd.read_csv(setup.patient_gexp_file, index_col=0).T
        patient_exp.index = [setup.case_id]
        setup.patient_exp = patient_exp
        patient_exp.to_csv(setup.patient_gexp_file)
        log('Habemus Genus Expressium *release the white smoke*')
    else:
        log(f'Checking if local file ({setup.input_expression_dir}) exist.')
        if os.path.isfile(setup.input_expression_dir):
            df = pd.read_csv(setup.input_expression_dir, index_col=0)
            setup.expression_input = df
            log("This file containes the expression of the PDXs. Printing dataframe's info:")
            log(setup.expression_input.info())
        else:
            log('File could not be located please check and run again.')
        patient_exp = df
        setup.patient_exp = patient_exp
        patient_exp.to_csv(setup.patient_gexp_file)
        log(f'File {setup.patient_gexp_file} saved successfully')
    
    pickle.dump(setup, file=open(os.path.join(setup.out_dir, setup.case_id+'_backup2_download.p'),'wb'))
#     pickle.dump(setup, file=open(setup.out_dir+'_backup2_download.p','wb'))
    log('Done preprocessing!')
    return setup
# Out:
# UIBuilder(function_import='download_and_preprocess_rnaseq', name='download_and_preprocess_rnaseq', params=[{'n…

# %% [markdown]
# # Classify the tumor by medulloblastoma subgroup and subtype

# %%
@genepattern.build_ui(
    description="This function classifies a medulloblastoma sample into a subgroup. Non-medulloblastoma samples are ignored.",
    parameters={
    "setup": {"default": "setup",
              "hide": False,
              "description": "The variable which has the setup information"},
    "output_var": {
        "default": "setup",
        "hide": True,
    },
})
def classify_sample(setup):
    # We have three datasets we can use to classify based on expression:
    # - [Cavalli et al. 2017](http://www.sciencedirect.com/science/article/pii/S1535610817302015) cohort. This cohort includes 763 tumors, and was used to define 12 finer-grained subtypes nested in the 4 subgroups. Both expression and methylation data are available.

    # - [Cho et al. 2011](http://www.mesirovlab.org/medulloblastoma/cho/) cohort. This paper identified two subtypes within G3 and two within G4, for a total of 6. It contains 194 tumors.

    # - [Northcott et al. 2017](http://www.nature.com/nature/journal/v547/n7663/full/nature22973.html) expression data (shared by Sebastian). The labels we have for this data are of the 4 basic subgroups only. There are 223 tumors.

    # When finer-grained subtypes are known, we perform the finer-grained classification first and also collapse the subtypes to the 4 basic subgroups, so as to report both subtype and subgroup probabilities. Classification is done using random forests.

    # Since the patient data are from the same platform and contain the same features each time, we can use pre-fit models to classify them. The classification methods also have a fallback in case the data looks different.

    # The tumor board is arranging for methylation data to be obtained from patient samples as well, since it seems it may be more informative than expression. Methylation data would also allow comparison to a large and variety collection of brain tumors, currently available through a DKFZ [web portal](https://www.molecularneuropathology.org/mnp).

    if setup.is_medullo:
        # Read in patient's gene-level RNASeq TPM data
        patient_exp = pd.read_csv(setup.patient_gexp_file, index_col=0)

        cavalli_subgroups, cavalli_subtypes = classify_cavalli(patient_exp)
        cavalli_subgroups.to_csv(setup.cavalli_subgroup_file)
        cavalli_subtypes.to_csv(setup.cavalli_subtype_file)
        setup.cavalli_subgroups = cavalli_subgroups
        setup.cavalli_subgroups.name='Cavalli'
        setup.cavalli_subtypes = cavalli_subtypes
        setup.cavalli_subtypes.name='Cavalli'

        cho_subgroups, cho_subtypes = classify_cho(patient_exp)
        cho_subtypes.to_csv(setup.cho_subtype_file)
        cho_subgroups.to_csv(setup.cho_subgroup_file)
        setup.cho_subtypes = cho_subtypes
        setup.cho_subtypes.name = 'Cho'
        setup.cho_subgroups = cho_subgroups
        setup.cho_subgroups.name = 'Cho'

        northcott_subgroups = classify_northcott(patient_exp)
        northcott_subgroups.to_csv(setup.northcott_subgroup_file)
        setup.northcott_subgroups = northcott_subgroups
        setup.northcott_subgroups.name = 'Northcott'
        

        make_medullo_classification_slide(setup.mtb_ppt_file,
                                          setup.cavalli_subgroup_file,
                                          setup.cavalli_subtype_file,
                                          setup.cho_subgroup_file,
                                          setup.cho_subtype_file,
                                          setup.northcott_subgroup_file)
        subgroups = pd.DataFrame(data=setup.cavalli_subgroups).join(setup.cho_subgroups).join(setup.northcott_subgroups)
        setup.subgroups = subgroups
        print(setup.subgroups)
        cavalli_subtypes = pd.DataFrame(data=setup.cavalli_subtypes)
        setup.cavalli_subtypes = cavalli_subtypes
        print(cavalli_subtypes)
        cho_subtypes = pd.DataFrame(pd.Series(index=[3,1,6,5,4,2], data=['SHH','G3-MYC','WNT','G3-photoreceptor','G4-Mixed','G4-neuronal'],name='Subtypes')).join(setup.cho_subtypes)
        setup.cho_subtypes = cho_subtypes
        print(cho_subtypes)
        
        log('Done! Move along')
    else:
        log('This is not medulloblastoma. Nothing to do here. Move along')
#     pickle.dump(setup, file=open(setup.out_dir+'_backup3_classify.p','wb'))
    pickle.dump(setup, file=open(os.path.join(setup.out_dir, setup.case_id+'_backup3_classify.p'),'wb'))
    
    return setup
# Out:
# UIBuilder(description='This function classifies a medulloblastoma sample into a subgroup. Non-medulloblastoma …

# %% [markdown]
# # Suggest drugs based on RNAseq data (DiSCoVER)

# %%
setup.discover_out_dir
# Out:
# '/pdx-hts/Notebooks/patients/DMB006/drug_suggestions/discover/cerebellar_stem'

# %%
@genepattern.build_ui(
  description="Run DiSCoVER on the provided sample and control.",
  parameters={
    "setup": {"default": "setup",
              "hide": False,
              "description": "The variable which has the setup information"},
    "output_var": {
        "default": "setup",
        "hide": True,
    },
})
def run_discover(setup):
    from rpy2.robjects import numpy2ri
    numpy2ri.activate()
#     from discover import discover_from_expression, plot_discover_from_expression
    from discover_temp import discover_from_expression, plot_discover_from_expression
    from drug_suggestion.expression.controls import load_control_exp
    patient_exp = pd.read_csv(setup.patient_gexp_file, index_col=0)
    control_exp = load_control_exp(setup.expression_control)
    log("About to perform DiSCoVER.")
    discover_results = discover_from_expression(exp=patient_exp, 
                                                control_exp=control_exp, 
                                                verbose=True)
    setup.raw_discover_results = discover_results
#     pickle.dump(setup, file=open(setup.out_dir+'_backup4-0_DISCoVER.p','wb'))
#     print(discover_results)
    # move some files created by DiSCoVER
#     for cl_name in ['ccle','ctrp','gdsc']:
#         os.rename(f"COSMIC_cell_lines_IDs_and_types_{cl_name}.csv", os.path.join(setup.out_dir, f"COSMIC_cell_lines_IDs_and_types_{cl_name}.csv"))
    
    log("DiSCoVER done!")
    numpy2ri.deactivate()
    
    log("Moving files contaiend enrichment of cell lines")
    for current_file in ['cell_lines_IDs_and_types_ccle.csv','cell_lines_IDs_and_types_COSMIC_IDS_gdsc.csv','cell_lines_IDs_and_types_ctrp.csv']:
        os.rename(current_file,os.path.join(setup.discover_out_dir,current_file))
        log(f'Moved {current_file} to {os.path.join(setup.discover_out_dir,current_file)}')
    
    
    log('Saving results to file.')
    # display(discover_results)
    discover_results.T.sort_values(by=setup.case_id, ascending=False).to_csv(setup.full_discover_results_file)
    log("Saving done!")
    log("NOT Restricting to clinically relevant drugs.")
    #Not all drugs in CCLE, CTRP, and GDSC are realistic candidates for treatment. We compiled a list of medications that are FDA-approved or in late-stage clinical trials, and Dr. Wechsler-Reya curated it to include only those that are relevant for treating brain tumors. Here we limit the results to these drugs and add Dr. Wechsler-Reya's mechanism-of-action annotations. To enable comparison of drug lists, drugs from the different sources have been mapped to PubChem compound IDs (CIDs) using [PubChemPy](http://pubchempy.readthedocs.io/en/latest/).
    from drug_suggestion.drug_annotation import subset_to_reasonable_drugs
    from drug_suggestion.expression.discover import load_discover_drug_to_cids
    disco2cid = load_discover_drug_to_cids()
    reasonable_results = subset_to_reasonable_drugs(discover_results, 
                                                disco2cid, 
                                                out_prefix='discover.{}'.format(setup.expression_control), 
                                                out_dir=setup.discover_out_dir)
    # This will override the file setup.rdrugs_discover_file
    all_drugs = format_drugs(discover_results, 
                                disco2cid, 
                                out_prefix='discover.{}'.format(setup.expression_control), 
                                out_dir=setup.discover_out_dir)
    log('Done restricting to clinically relevant drugs!')
    
##     log('making a discover illustrative method')
##     from drug_suggestion.expression.discover import plot_discover_from_expression
##     plot_discover_from_expression(case_id, 
##                                   discover_results, 
##                                   exp=patient_exp,
##                                   control_exp=control_exp,
##                                   cl='ctrp',
##                                   out_file=discover_heatmap_file)
##     make_discover_workflow_slide(mtb_ppt_file, discover_heatmap_file)
    log('Making the DiSCoVER powerpoint.')
    rdrugs_discover = pd.read_csv(setup.rdrugs_discover_file, index_col=None)

    
    # Using all of the drugs
    log('Using all of the drugs')
    df = split_discover_dataframe(df=rdrugs_discover)
    df = rank_drugs_discover(df)
#     df.head()
    make_exp_drug_ranking_results_slide(setup.mtb_ppt_file, df.head(20), setup.expression_control, method='DiSCoVER')
    log('Done making the DiSCoVER powerpoint slide!')
    log('Savig the variables to a file.')
    setup.discover_results = discover_results
    setup.disco2cid = disco2cid
    setup.control_exp = control_exp
    setup.reasonable_results = reasonable_results
    setup.df = df
    log('Saving the formatted results of DiSCoVER to a csv')
    df.to_csv(os.path.join(setup.out_dir, setup.case_id+'_formated_DISCoVER_results.csv'))
#     pickle.dump(setup, file=open(setup.out_dir+'_backup4_DISCoVER.p','wb'))
    pickle.dump(setup, file=open(os.path.join(setup.out_dir, setup.case_id+'_backup4_DISCoVER.p'),'wb'))
#     pickle.dump(setup, file=open(setup.case_id+'_DISCoVER.p','wb'))
    log('Done savig the variables to a file!')
    
    log('Done with all the taks in this cell. Move along.')
    return setup
# Out:
# UIBuilder(description='Run DiSCoVER on the provided sample and control.', function_import='run_discover', name…

# %% [markdown]
# # Run CMap

# %%
# delete
case_id='BT084'
print('======================================')
print("Step 1: read_user_input")
print('======================================')
setup = read_user_input(case_id, patient_dir=case_id, dna_nexus_bool=False, is_medullo=True, control='original',custom_control_expression='N/A')
print('======================================')
print("Step 2: download_and_preprocess_rnaseq")
print('======================================')
setup = download_and_preprocess_rnaseq(setup)
print('======================================')
print("Step 3: classify_sample")
print('======================================')
if CLASSIFY:
    setup = classify_sample(setup)
else:
     print("These are not the analyses you are looking for. Move along!")   
print('======================================')
print("Step 4: run_discover")
print('======================================')
setup = run_discover(setup)
print('======================================')
print("Step 5: run_cmap")
print('======================================')
setup = make_cmap_slide(setup)
setup = merge_discover_and_cmap(setup)
print(f'All analyses completed suscessfully with "patient" {case_id}')

# %%
from cmap import make_cmap_genesets, write_cmap_genesets
from cmap import read_cmap_gct, load_cmap_drug_to_cids
from controls import load_control_exp

@genepattern.build_ui(
  description="This function parses CMap's results.",
  parameters={
    "setup": {"default": "setup",
              "hide": False,
              "description": "The variable which has the setup information"},
    "output_var": {
        "default": "setup",
        "hide": True,
    },
})
def make_cmap_slide(setup):
    log('About to parse CMap results.')
    patient_exp = pd.read_csv(setup.patient_gexp_file, index_col=0)
    control_exp = load_control_exp(setup.expression_control)
    cmap_genesets = make_cmap_genesets(patient_exp, control_exp)
    write_cmap_genesets(cmap_genesets, setup.cmap_out_dir)

    # must match path to downloaded .gct file
    cmap_gct = os.path.join(setup.cmap_out_dir, 'cmap_result.gct')

    if os.path.exists(cmap_gct):
        cmap_ranked_drugs = read_cmap_gct(cmap_gct)
        cmap_ranked_drugs.columns = [setup.case_id]
        cmap_ranked_drugs.to_csv(setup.cmap_all_ranked_drugs_file)
        cmap2cid = load_cmap_drug_to_cids()
        cmap_reasonable = subset_to_reasonable_drugs(cmap_ranked_drugs.T, 
                                   cmap2cid,
                                   out_prefix='cmap.{}'.format(setup.expression_control), 
                                   out_dir=setup.cmap_out_dir).sort_values(by=setup.case_id, ascending=False)
        rdrugs_cmap = pd.read_csv(setup.cmap_reasonable_ranked_drugs_file, index_col=None)
        make_exp_drug_ranking_results_slide(setup.mtb_ppt_file, rdrugs_cmap, setup.expression_control, method='CMap')
        setup.rdrugs_cmap = rdrugs_cmap
        setup.cmap_flag = True
        pickle.dump(setup, file=open(os.path.join(setup.out_dir, setup.case_id+'_backup5_CMap.p'),'wb'))
        log("done!")
    else:
        setup.cmap_flag = False
        log(f"cmap_result.gct not found! (It should be present in the directiory {setup.cmap_out_dir}).")
        log("Try again if you'd like to see CMap results.")
        log("Hint, you may want to go here:")
        log("https://clue.io/l1000-query#individual")
    return setup
# Out:
# UIBuilder(description="This function parses CMap's results.", function_import='make_cmap_slide', name='make_cm…

# %%
setup = make_cmap_slide(setup)

# %%
def add_cmap_to_split_df(discover,cmap):
    df = discover.rename(index=str, columns={"score": "DiSCoVER", "moa":"MoA"},inplace=False)
    for index, row in cmap.iterrows():
        drug = row['drug'].lower()
        try:
            if str(df.loc[drug,'CMAP']) != 'nan':
                #drug already exists and a CMAP score has been added
                df.loc[drug,'CMAP'] = np.nanmean([row['score'], df.loc[drug,'CMAP']])
            else:
                # drug already exists but a CMAP score has not been added
                df.loc[drug,'CMAP'] = row['score']
        except KeyError:
            # drug didn't exist therefore a CMAP score had not been added
            df.loc[drug,'CMAP'] = row['score']    
            df.loc[drug,'MoA'] = row['moa']
            df.loc[drug,'drug'] = 'cmap_'+drug
        if str(df.loc[drug,'evidence'])=='nan': #numpy is not letting me use np.isnan()
            df.loc[drug,'evidence'] = '...'+sign_to_letter[str(np.sign(row['score']))]
        else:
            df.loc[drug,'evidence'] = str(df.loc[drug,'evidence'])+sign_to_letter[str(np.sign(row['score']))]
    
    #update those rows which are not in cmap
    for index, row in df.iterrows():
        if len(row['evidence'])==3:
            df.loc[index,'evidence']  = df.loc[index,'evidence']+'.'            
    
    return df[['drug','MoA','GDSC','CTRP','CCLE','DiSCoVER','CMAP','evidence']]


def custom_mean(ser):
    if pd.isna(ser['DiSCoVER']):
        to_mean = ser['CMAP rank']
    elif pd.isna(ser['CMAP']):
        to_mean = ser['DiSCoVER rank']
    else:
        to_mean = ser[['DiSCoVER rank','CMAP rank']].mean()
#         to_mean = np.mean(ser['DiSCoVER rank','CMAP rank'])
    return to_mean


def rank_combined_df(df, strict_rules = False):
#     df['average'] = df.drop(['MoA','GDSC','CTRP','CCLE','support'],axis=1,inplace=False).mean(axis=1,skipna=True).round(3)
    df.sort_values(by=['DiSCoVER'],ascending=False,axis=0,inplace=True)
    df['DiSCoVER rank'] = range(1, len(df) + 1)
    df.sort_values(by=['CMAP'],ascending=False,axis=0,inplace=True)
    df['CMAP rank'] = range(1, len(df) + 1)
    
    # compute average rank
    
    #A simple average does not do the trick. It penalizes drugs which show up in only one of the methods
    # df['Average rank'] = df[['DiSCoVER rank','CMAP rank']].mean(axis=1)
    df['Average rank'] = df[['DiSCoVER','CMAP','DiSCoVER rank','CMAP rank']].apply(custom_mean, axis=1)
    
    df.sort_values(by=['Average rank'],ascending=True,axis=0,inplace=True)
    
    if strict_rules:
        df = df[((df['DiSCoVER']>0.001).values) & ((df['CMAP']>0.001).values)]
#     combined_df = combined_df[((combined_df['DiSCoVER']>0.001).values) & ((combined_df['CMAP']>0.001).values)]

    return df.drop(['GDSC','CTRP','CCLE'],axis=1,inplace=False)

@genepattern.build_ui(
  description="This function merges the results of DiSCoVER and CMap.",
  parameters={
    "setup": {"default": "setup",
              "hide": False,
              "description": "The variable which has the setup information"},
    "output_var": {
        "default": "setup",
        "hide": True,
    },
})
def merge_discover_and_cmap(setup):
    if setup.cmap_flag:
        log('Merging results from DiSCoVER and CMap.')
        combined_df = add_cmap_to_split_df(discover=setup.df,cmap=setup.rdrugs_cmap)
        to_slide = rank_combined_df(combined_df)

        #this is commented out, since it is not used for the paper
        make_intersection_slide(setup.mtb_ppt_file, to_slide, setup.expression_control, method='DiSCoVER ∩ CMap')

        log("Done Merging results from DiSCoVER and CMap!")
        log("Saving combined_df and to_slide on setup variable")
        setup.combined_df = combined_df
        setup.to_slide = to_slide
        log(f"Saving the combined DiSCoVER+CMap resuls to a csv called {setup.case_id+'_combined_DISCoVER_and_CMap_results.csv'}")
        setup.combined_df.to_csv(os.path.join(setup.out_dir, setup.case_id+'_combined_DISCoVER_and_CMap_results.csv'))
        pickle.dump(setup, file=open(os.path.join(setup.out_dir, setup.case_id+'_backup6_combined_results.p'),'wb'))
        log("Done done!")
        
    else:
        log('CMap has not run! Nothing to do here.')
    
    return setup
# Out:
# UIBuilder(description='This function merges the results of DiSCoVER and CMap.', function_import='merge_discove…

# %%
setup.to_slide

# %%
d_names = [
'monafide',
'bx-912',
'linsitinib',
'ABT-737',
'anisomycin',
'GSK1070916',
'topotecan',
'etoposide'
]

d_names = [x.lower() for x in d_names]

# %%
setup.combined_df[setup.combined_df.index.isin(d_names)]
