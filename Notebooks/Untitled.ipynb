# %%
import ccalnoir as ccal
import pandas as pd

# %%
subgroup='G3'

# %%
effective_drugs = pd.read_table(f'results/{subgroup}/significance.match.txt',index_col=0)
ccal.plot_match_panel()
# Out:
#                  Score(0.95 MoE)  0.95 MoE   p-value       FDR     Score
# Name
# marinopyrrole a              NaN  0.055646  0.000015  0.005000  0.714686
# ql-xii-61                    NaN  0.056195  0.000015  0.005000  0.713319
# 5-fluorouracil               NaN  0.047322  0.000030  0.006667  0.710768
# irinotecan                   NaN  0.045173  0.000045  0.006667  0.709439
# topotecan                    NaN  0.044894  0.000060  0.006667  0.689591
# snx-2112                     NaN  0.060222  0.000060  0.006667  0.663137
# pha-793887                   NaN  0.046606  0.000104  0.010000  0.655463
# hyperforin                   NaN  0.044912  0.000119  0.010000  0.637081
# paclitaxel                   NaN  0.047264  0.000268  0.020000  0.622321
# brd-k35604418                NaN  0.030122  0.000327  0.020000  0.582529
# ml031                        NaN       NaN  0.000327  0.020000  0.573046
# kin001-270                   NaN       NaN  0.000521  0.029167  0.563004
# ...
