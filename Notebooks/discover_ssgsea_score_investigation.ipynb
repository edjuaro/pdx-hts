# %%
import pandas as pd
import os

# %%
discover_data_dir = 'discover_temp'

# %%
cl_name = 'ccle'
hdf_file = os.path.join(discover_data_dir, cl_name, 'store.h5')
ccle_exp = pd.read_hdf(hdf_file, 'exp')
ccle_dr = pd.read_hdf(hdf_file, 'dr')

display(cl_name.upper())
display(ccle_exp.reindex(sorted(ccle_exp.columns), axis=1).head())
display(ccle_dr.reindex(sorted(ccle_dr.columns), axis=1).head())
# Out:
# 'CCLE'
#            A1BG  A1BG-AS1     A1CF      A2M  A2M-AS1    A2ML1  A2ML1-AS1  \
# 22RV1   0.36230   4.81588  5.65486  1.98954  1.27348  0.01960    0.91070
# 42MGBA  3.06452   9.15532  0.00000  0.02477  0.00000  0.00000    0.09900
# 5637    0.01339   0.06459  0.00000  0.03442  0.03198  1.60543    0.55016
# 639V    2.24186   4.48351  0.00000  0.00963  0.09945  0.00260    0.67367
# 697     3.69805   6.48321  0.00000  0.12765  0.01543  0.00629    1.13845
#
#         A2ML1-AS2    A2MP1  A3GALT2   ...         ZWINT     ZXDA     ZXDB  \
# 22RV1         0.0  0.11096  0.04151   ...     100.66772  0.79100  2.74955
# 42MGBA        0.0  0.00192  0.13572   ...      43.94226  0.37833  0.75398
# 5637          0.0  0.00000  0.00737   ...      45.25700  0.67794  2.13364
# 639V          0.0  0.00000  0.03299   ...      77.31774  1.23546  2.86091
# 697           0.0  0.00000  0.05597   ...      85.65266  0.09078  1.79397
#
#            ZXDC   ZYG11A  ZYG11AP1   ZYG11B       ZYX    ZZEF1     ZZZ3
# ...

# %%
cl_name = 'ctrp'
hdf_file = os.path.join(discover_data_dir, cl_name, 'store.h5')
cl_exp = pd.read_hdf(hdf_file, 'exp')
cl_dr = pd.read_hdf(hdf_file, 'dr')

display(cl_name.upper())
display(cl_exp.reindex(sorted(cl_exp.columns), axis=1).head())
display(cl_dr.reindex(sorted(cl_dr.columns), axis=1).head())
# Out:
# 'CTRP'
#              A1BG  A1BG-AS1     A1CF      A2M  A2M-AS1    A2ML1  A2ML1-AS1  \
# SUIT2     0.00570   0.15225  0.08548  0.05126  0.00000  0.00000    2.32671
# CAL51     1.68293   4.20714  0.00000  0.26831  0.11161  0.32769    1.85490
# NCIH1869  0.07430   1.25329  0.00367  0.00502  0.14315  0.00406    0.06023
# LOXIMVI   0.00000   0.01054  0.00888  0.03499  0.00377  0.00123    1.05777
# CCFSTTG1  1.81932   7.31746  0.00000  3.12043  0.02940  0.00000    0.00000
#
#           A2ML1-AS2    A2MP1  A3GALT2   ...        ZWINT     ZXDA     ZXDB  \
# SUIT2           0.0  0.00000  0.00000   ...     99.94039  1.01426  2.22432
# CAL51           0.0  0.00000  0.02012   ...     83.69485  1.69063  3.40899
# NCIH1869        0.0  0.00000  0.00000   ...     92.62543  0.62907  2.14032
# LOXIMVI         0.0  0.00177  0.03907   ...     39.14648  0.54966  1.52497
# CCFSTTG1        0.0  0.00460  0.00000   ...     92.67213  0.77836  1.41978
#
# ...

# %%
cl_name = 'gdsc'
hdf_file = os.path.join(discover_data_dir, cl_name, 'store.h5')
cl_exp = pd.read_hdf(hdf_file, 'exp')
cl_dr = pd.read_hdf(hdf_file, 'dr')

display(cl_name.upper())
display(cl_exp.reindex(sorted(cl_exp.columns), axis=1).head())
display(cl_dr.reindex(sorted(cl_dr.columns.astype(str)), axis=1).head())
# Out:
# 'GDSC'
#                     A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# cosmic_905954   5.377902  2.972059  9.550481  2.868133  2.663215  3.074459
# cosmic_909976   5.936305  2.849818  3.593057  2.778632  2.983081  3.155452
# cosmic_1330983  3.446559  3.093062  3.509003  2.773571  2.986146  3.231853
# cosmic_1503362  3.138582  2.928052  3.473562  2.935903  2.803306  3.350616
# cosmic_906826   6.208447  2.981775  3.133883  2.652527  2.759164  3.339829
#
#                    A4GNT      AAAS      AACS    AACSP1    ...         ZUP1  \
# cosmic_905954   3.132034  4.652471  3.562925  3.213880    ...     6.572749
# cosmic_909976   3.191348  5.059145  3.911432  4.879302    ...     6.460039
# cosmic_1330983  3.139554  4.651155  3.394892  3.080344    ...     7.059113
# cosmic_1503362  3.112889  4.563609  3.738898  3.156752    ...     6.449683
# cosmic_906826   3.298572  4.589827  4.082866  3.058922    ...     6.297081
#
# ...

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cl_dr.min().min()
# Out:
# 0.00343348

# %%
cl_dr.max().max()
# Out:
# 0.99863886000000002

# %%
cl_exp.min().min()
# Out:
# 2.09425127453073

# %%
cl_exp.max().max()
# Out:
# 13.960294847954801

# %%
2**14
# Out:
# 16384

# %%
ccle_exp.max().max()
# Out:
# 106460.57031

# %%
gdsc_rma = pd.read_table('discover_temp/Cell_line_RMA_proc_basalExp.txt', index_col = 0).drop('GENE_title',axis=1).T

# %%
gdsc_rma.head()
# Out:
# GENE_SYMBOLS    TSPAN6      TNMD       DPM1     SCYL3  C1orf112       FGR  \
# DATA.906826   7.632023  2.964585  10.379553  3.614794  3.380681  3.324692
# DATA.687983   7.548671  2.777716  11.807341  4.066887  3.732485  3.152404
# DATA.910927   8.712338  2.643508   9.880733  3.956230  3.236620  3.241246
# DATA.1240138  7.797142  2.817923   9.883471  4.063701  3.558414  3.101247
# DATA.1240139  7.729268  2.957739  10.418840  4.341500  3.840373  3.001802
#
# GENE_SYMBOLS       CFH     FUCA2      GCLC      NFYA    ...     LINC00526  \
# DATA.906826   3.566350  8.204530  5.235118  5.369039    ...      6.786925
# DATA.687983   7.827172  6.616972  5.809264  7.209653    ...      5.317911
# DATA.910927   2.931034  8.191246  5.426841  5.120747    ...      3.143006
# DATA.1240138  7.211707  8.630643  5.617714  4.996434    ...      3.153896
# DATA.1240139  3.375422  8.296950  5.669418  4.180205    ...      3.652660
#
# GENE_SYMBOLS      PPY2       NaN       NaN  KRT18P55       NaN  POLRMTP1  \
# ...

# %%
display(cl_exp.reindex(sorted(cl_exp.columns), axis=1).head())
# Out:
#                     A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# cosmic_905954   5.377902  2.972059  9.550481  2.868133  2.663215  3.074459
# cosmic_909976   5.936305  2.849818  3.593057  2.778632  2.983081  3.155452
# cosmic_1330983  3.446559  3.093062  3.509003  2.773571  2.986146  3.231853
# cosmic_1503362  3.138582  2.928052  3.473562  2.935903  2.803306  3.350616
# cosmic_906826   6.208447  2.981775  3.133883  2.652527  2.759164  3.339829
#
#                    A4GNT      AAAS      AACS    AACSP1    ...         ZUP1  \
# cosmic_905954   3.132034  4.652471  3.562925  3.213880    ...     6.572749
# cosmic_909976   3.191348  5.059145  3.911432  4.879302    ...     6.460039
# cosmic_1330983  3.139554  4.651155  3.394892  3.080344    ...     7.059113
# cosmic_1503362  3.112889  4.563609  3.738898  3.156752    ...     6.449683
# cosmic_906826   3.298572  4.589827  4.082866  3.058922    ...     6.297081
#
# ...

# %%
len(cl_exp.columns)
# Out:
# 16489

# %%
rma = gdsc_rma.loc[:,cl_exp.columns]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
# display(cl_exp.reindex(sorted(cl_exp.columns), axis=1).head())
display(cl_exp.loc[sorted(cl_exp.index),sorted(cl_exp.columns)].head())
# Out:
#                     A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# cosmic_1240121  4.602184  3.130574  3.362240  3.021673  2.781981  3.764415
# cosmic_1240122  4.066945  2.956743  3.195814  5.977871  2.826886  3.275947
# cosmic_1240123  3.489203  6.295012  3.567860  2.873906  2.990334  2.929577
# cosmic_1240124  3.201897  6.205773  3.310717  2.916515  2.882023  3.055106
# cosmic_1240125  4.833230  3.070527  4.544687  2.785403  2.670398  3.143576
#
#                    A4GNT      AAAS      AACS    AACSP1    ...         ZUP1  \
# cosmic_1240121  3.228677  4.792884  4.784980  3.369818    ...     7.617852
# cosmic_1240122  3.055744  5.488174  3.929538  3.140269    ...     6.059221
# cosmic_1240123  3.152893  4.735084  4.949065  2.983336    ...     6.899960
# cosmic_1240124  3.306700  4.894648  4.598991  3.163864    ...     6.778507
# cosmic_1240125  3.846602  4.404041  4.857497  3.190224    ...     5.391286
#
# ...

# %%
# display(rma.reindex(sorted(rma.columns), axis=1).head())
display(rma.loc[sorted(rma.index),sorted(rma.columns)].head())
# Out:
# GENE_SYMBOLS       A1BG      A1CF       A2M     A2ML1  A3GALT2    A4GALT  \
# DATA.11223344  2.970296  6.504559  3.491545  2.955931      NaN  3.388877
# DATA.1240121   4.602184  3.130574  3.362240  3.021673      NaN  3.764415
# DATA.1240122   4.066945  2.956743  3.195814  5.977871      NaN  3.275947
# DATA.1240123   3.489203  6.295012  3.567860  2.873906      NaN  2.929577
# DATA.1240124   3.201897  6.205773  3.310717  2.916515      NaN  3.055106
#
# GENE_SYMBOLS      A4GNT      AAAS      AACS    AACSP1    ...     ZUP1  \
# DATA.11223344  3.243962  4.811069  4.575174  3.242027    ...      NaN
# DATA.1240121   3.228677  4.792884  4.784980  3.369818    ...      NaN
# DATA.1240122   3.055744  5.488174  3.929538  3.140269    ...      NaN
# DATA.1240123   3.152893  4.735084  4.949065  2.983336    ...      NaN
# DATA.1240124   3.306700  4.894648  4.598991  3.163864    ...      NaN
#
# GENE_SYMBOLS     ZWILCH      ZWINT      ZXDB      ZXDC    ZYG11A    ZYG11B  \
# ...

# %%
rma.min().min()
# Out:
# 2.0651824797738998

# %%
rma.max().max()
# Out:
# 13.960294847954801

# %%
cl_exp.loc['cosmic_688022',:]
# Out:
# TSPAN6        7.208878
# TNMD          2.896522
# DPM1          9.359734
# SCYL3         4.141652
# C1orf112      3.666543
# FGR           3.060136
# CFH           3.295347
# FUCA2         6.153828
# GCLC          5.005108
# NFYA          5.953550
# STPG1         4.037227
# NIPAL3        8.018631
# LAS1L         4.345359
# ENPP4         5.162496
# SEMA3F        3.734434
# CFTR          3.278274
# ANKIB1        8.263734
# KRIT1         4.059028
# RAD52         3.497440
# BAD           7.262195
# LAP3          5.315013
# CD99          4.006055
# HS3ST1        3.506090
# AOC1          3.185835
# WNT16         2.770033
# HECW1         2.832555
# MAD1L1        4.644715
# LASP1         3.881355
# SNX11         4.889853
# TMEM176A      3.269437
#                 ...
# LINC02308     3.402098
# LINC00638     3.196345
# OR4C13        3.294631
# CEP95         7.450036
# SMIM6         3.593551
# LINC01895     3.210119
# LINC00596     3.006055
# OR4N3P        3.365978
# MRPL46        8.263464
# ...

# %%
up = pd.read_table('discover_temp/EXAMPLE_UP.txt',header=None)
down = pd.read_table('discover_temp/EXAMPLE_DOWN.txt',header=None)
display(up.head())
display(down.head())
# Out:
#        0
# 0   CHGA
# 1   ST18
# 2    PRL
# 3  PRAME
# 4   CA10
#        0
# 0    CA2
# 1   PLP1
# 2   LRP4
# 3  RPE65
# 4   CCL2

# %%
def summary(df,line,up,down):
    print('---')
    print(len(set(df.columns).intersection(set(up[0]))))
#     ranked = pd.DataFrame(data = df.loc[line,:].sort_values(ascending=False))
#     ranked['rank'] = ranked.rank(ascending=False)
#     print(ranked.reindex(index=up[0],columns=['rank']).head())
#     up_regulated = int(ranked.reindex(index=up[0],columns=['rank']).mean())
#     dn_regulated = int(ranked.reindex(index=down[0],columns=['rank']).mean())
#     print(f'For line {line}, mean up is {up_regulated}, mean down is {dn_regulated}, total={len(ranked)}')

# %%
df=cl_exp
line=""
genes=list(up[0].head())+list(down[0].head())

# %%
# Out:
# 5157.8
# 12007.4

# %%
# summary(df=cl_exp,line="cosmic_688022",genes=list(up[0].head())+list(down[0].head()))
summary(df=cl_exp,line='cosmic_688022',up=up,down=down)
summary(df=cl_exp,line='cosmic_905938',up=up,down=down)
summary(df=ccle_exp,line='NCIH1184',up=up,down=down)
summary(df=ccle_exp,line='PK59',up=up,down=down)
# Out:
# ---
# 141
# ---
# 141
# ---
# 148
# ---
# 148

# %%
import cuzcatlan as cusca

# %%
cl_exp.loc[['cosmic_688022','cosmic_905938'],:].drop('Description',axis=1).T
# Out:
#             cosmic_688022  cosmic_905938
# TSPAN6           7.208878       3.350985
# TNMD             2.896522       2.996260
# DPM1             9.359734       9.949657
# SCYL3            4.141652       4.253713
# C1orf112         3.666543       4.245576
# FGR              3.060136       7.928539
# CFH              3.295347       3.316754
# FUCA2            6.153828       7.008536
# GCLC             5.005108       5.617838
# NFYA             5.953550       4.890746
# STPG1            4.037227       3.372380
# NIPAL3           8.018631       6.807068
# LAS1L            4.345359       4.556737
# ENPP4            5.162496       4.092816
# SEMA3F           3.734434       4.179462
# CFTR             3.278274       3.064153
# ANKIB1           8.263734       6.789567
# KRIT1            4.059028       3.842526
# RAD52            3.497440       3.604054
# BAD              7.262195       5.612724
# LAP3             5.315013       6.329600
# CD99             4.006055       7.286792
# ...

# %%
cusca.df2gct(cl_exp.loc[['cosmic_688022','cosmic_905938'],:].drop('Description',axis=1).T,name='GDSC_2.gct',add_dummy_descriptions=True)
cusca.df2gct(cl_exp.drop('Description',axis=1).T,name='GDSC.gct',add_dummy_descriptions=True)

# %%
cusca.df2gct(ccle_exp.loc[['NCIH1184','PK59'],:].T,name='CCLE_2.gct',add_dummy_descriptions=True)
cusca.df2gct(ccle_exp.T,name='CCLE.gct',add_dummy_descriptions=True)

# %%
print('Top cell line', 'cosmic_688022')
print(cl_exp.loc['cosmic_688022',list(up[0].head())])
print('---')
print(cl_exp.loc['cosmic_688022',:].mean())
print('---')
print(cl_exp.loc['cosmic_688022',list(down[0].head())])
print("===============")
print('Bottom cell line')
print(cl_exp.loc['cosmic_905938',list(up[0].head())])
print('---')
print(cl_exp.loc['cosmic_905938',:].mean())
print('---')
print(cl_exp.loc['cosmic_905938',list(down[0].head())])
# Out:
# Top cell line cosmic_688022
# CHGA     10.298757
# ST18      7.025963
# PRL       9.942428
# PRAME     3.192606
# CA10      3.424416
# Name: cosmic_688022, dtype: float64
# ---
# 4.8492562326
# ---
# CA2      3.270966
# PLP1     2.981469
# LRP4     5.175501
# RPE65    2.876125
# CCL2     3.063727
# Name: cosmic_688022, dtype: float64
# ...
# Bottom cell line
# CHGA     3.319490
# ST18     2.869347
# PRL      2.904672
# PRAME    8.509505
# CA10     2.957446
# Name: cosmic_905938, dtype: float64
# ---
# 4.87923070639
# ---
# CA2       8.260049
# PLP1      3.040034
# LRP4      3.427818
# RPE65     3.018293
# CCL2     10.998014
# Name: cosmic_905938, dtype: float64

# %%
print(ccle_exp.loc['NCIH1184',list(up[0].head())])
print('---')
print(ccle_exp.loc['NCIH1184',:].mean())
print('---')
print(ccle_exp.loc['NCIH1184',list(down[0].head())])
# Out:
# CHGA      32.55278
# ST18       8.21094
# PRL        0.28832
# PRAME    108.81816
# CA10       0.01535
# Name: NCIH1184, dtype: float64
# ---
# 8.99078194642
# ---
# CA2      0.04888
# PLP1     0.48233
# LRP4     1.04033
# RPE65    0.00000
# CCL2     4.29343
# Name: NCIH1184, dtype: float64

# %%
cl_exp.head()
# Out:
#                   TSPAN6      TNMD       DPM1     SCYL3  C1orf112       FGR  \
# cosmic_905954   7.319066  2.880745  10.278546  4.028248  3.794181  3.202882
# cosmic_909976   3.301585  2.821866   9.909161  5.917795  4.239273  3.361875
# cosmic_1330983  3.247073  2.760609   9.810807  5.142944  4.329999  4.161669
# cosmic_1503362  7.629337  2.875900  10.781083  3.657659  4.096670  3.158125
# cosmic_906826   7.632023  2.964585  10.379553  3.614794  3.380681  3.324692
#
#                      CFH     FUCA2      GCLC      NFYA    ...        OR1D5  \
# cosmic_905954   3.096177  8.390212  5.243852  5.611127    ...     3.315138
# cosmic_909976   4.157523  3.234626  5.268448  4.997476    ...     4.102860
# cosmic_1330983  3.432480  7.486630  6.315711  6.063547    ...     4.230853
# cosmic_1503362  3.232647  7.808810  6.753691  4.878049    ...     3.687632
# cosmic_906826   3.566350  8.204530  5.235118  5.369039    ...     3.134197
#
# ...

# %%
gdsc_module = pd.read_table('discover_temp/GDSC.PROJ.gct',header=2, index_col=0).drop('Description',axis=1).T
gdsc_notebook = pd.read_excel('discover_temp/processed_cell_lines_info_gdsc.xlsx',index_col=0)
gdsc_to_plot = pd.DataFrame(data=gdsc_notebook['DMB006'])
gdsc_to_plot['Module'] = gdsc_module['up_signature']
plt.scatter(x=gdsc_to_plot['DMB006'].values,y=gdsc_to_plot['Module'].values)

# %%
ccle_module = pd.read_table('discover_temp/CCLE.PROJ.gct',header=2, index_col=0).drop('Description',axis=1).T
ccle_notebook = pd.read_excel('discover_temp/processed_cell_lines_info_ccle.xlsx',index_col=0)
ccle_to_plot = pd.DataFrame(data=ccle_notebook['DMB006'])
ccle_to_plot['Module'] = ccle_module['up_signature']
plt.scatter(x=ccle_to_plot['DMB006'].values,y=ccle_to_plot['Module'].values)
